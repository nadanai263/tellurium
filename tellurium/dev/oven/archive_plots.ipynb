# %% [markdown]
# # Combine Archives
#
# jupyter notebook --NotebookApp.iopub_data_rate_limit=10000000000

# %%
from __future__ import print_function
import os
import importlib
import tellurium
import matplotlib

# tellurium.setDefaultPlottingEngine("matplotlib")
tellurium.setDefaultPlottingEngine("plotly")

outputDir = "./__tellurium__"
if not os.path.exists(outputDir):
    os.makedirs(outputDir)

omex_dir = "./omex"
archives = [f for f in os.listdir(omex_dir) if os.path.isfile(os.path.join(omex_dir, f))]
f_archives = [os.path.join(omex_dir, archive) for archive in archives]

if False:
    for f in f_archives:
        print("*" * 80)
        print(f)
        print("*" * 80)
        dgs = tellurium.executeCombineArchive(f, printPython=False, outputDir=outputDir, saveOutputs=True)
    
dgs = tellurium.executeCombineArchive("./omex/L1V3_parameter-scan-2d.omex", printPython=True, outputDir=outputDir, saveOutputs=True)
# Out:
# """
# ####################################################################################################
#                             tellurium 2.0.2
# -+++++++++++++++++-         Python Environment for Modeling and Simulating Biological Systems
#  .+++++++++++++++.
#   .+++++++++++++.           Homepage:      http://tellurium.analogmachine.org/
# -//++++++++++++/.   -:/-`   Documentation: https://tellurium.readthedocs.io/en/latest/index.html
# .----:+++++++/.++  .++++/   Forum:         https://groups.google.com/forum/#!forum/tellurium-discuss
#       :+++++:  .+:` .--++   Bug reports:   https://github.com/sys-bio/tellurium/issues
#        -+++-    ./+:-://.   Repository:    https://github.com/sys-bio/tellurium
#         .+.       `...`
#
# SED-ML simulation experiments: http://www.sed-ml.org/
#     sedmlDoc: L1V3
#     inputType:      'SEDML_FILE'
#     workingDir:     '/tmp/tmpq2rr46lx'
#     saveOutputs:    'True'
#     outputDir:      './__tellurium__'
#     plottingEngine: '<PlotlyEngine>'
#
# Linux-4.10.0-35-generic-x86_64-with-Ubuntu-16.04-xenial
# python 3.6.2 (default, Jul 20 2017, 08:43:29)
# [GCC 5.4.1 20170519]
# ####################################################################################################
# """
# import tellurium as te
# from roadrunner import Config
# from tellurium.sedml.mathml import *
# # from tellurium.sedml.tesedml import process_trace, terminate_trace, fix_endpoints
#
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# try:
#     import tesedml as libsedml
# except ImportError:
#     import libsedml
# import pandas
# import os.path
# Config.LOADSBMLOPTIONS_RECOMPILE = True
#
# workingDir = r'/tmp/tmpq2rr46lx'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model1>
# model1 = te.loadSBMLModel(os.path.join(workingDir, 'BorisEJB.xml'))
#
#
#
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # not part of any DataGenerator: task0
# # Task <task1>
# task1 = np.empty(shape=[9, 101], dtype=object)
#
#
# # Task: <task1>
# __range__current = [1.0, 5.0, 10.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0]
# for __k__current, __value__current in enumerate(__range__current):
#     if __k__current == 0:
#         model1.reset()
#
#
#     # Task: <task2>
#     __range__current1 = np.linspace(start=1.0, stop=40.0, num=101)
#     for __k__current1, __value__current1 in enumerate(__range__current1):
#         if __k__current1 == 0:
#             model1.reset()
#         # Task: <task0>
#         model1.setSteadyStateSolver('nleq')
#         if model1.conservedMoietyAnalysis == False: model1.conservedMoietyAnalysis = True
#         model1['J1_KK2'] = __value__current
#         model1['J4_KK5'] = __value__current1
#         model1.steadyStateSelections = ['[MKK]', 'J1_KK2', '[MKK_P]', 'J4_KK5', '[MKK_PP]']
#         model1.simulate()
#         task0 = model1.steadyStateNamedArray()
#         task1[__k__current, __k__current1] = task0
# # Task <task2>
# # not part of any DataGenerator: task2
#
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <J4_KK5_1>
# __var__J4_KK5 = np.empty(shape=task1.shape, dtype=object)
# for __index__, __item__ in np.ndenumerate(task1):
#     __var__J4_KK5[__index__] = __item__['J4_KK5']
# J4_KK5_1 = __var__J4_KK5
# # DataGenerator <J1_KK2_1>
# __var__J1_KK2 = np.empty(shape=task1.shape, dtype=object)
# for __index__, __item__ in np.ndenumerate(task1):
#     __var__J1_KK2[__index__] = __item__['J1_KK2']
# J1_KK2_1 = __var__J1_KK2
# # DataGenerator <MKK_1>
# __var__MKK = np.empty(shape=task1.shape, dtype=object)
# for __index__, __item__ in np.ndenumerate(task1):
#     __var__MKK[__index__] = __item__['[MKK]']
# MKK_1 = __var__MKK
# # DataGenerator <MKK_P_1>
# __var__MKK_P = np.empty(shape=task1.shape, dtype=object)
# for __index__, __item__ in np.ndenumerate(task1):
#     __var__MKK_P[__index__] = __item__['[MKK_P]']
# MKK_P_1 = __var__MKK_P
# # DataGenerator <MKK_PP_1>
# __var__MKK_PP_1 = np.empty(shape=task1.shape, dtype=object)
# for __index__, __item__ in np.ndenumerate(task1):
#     __var__MKK_PP_1[__index__] = __item__['[MKK_PP]']
# MKK_PP_1 = __var__MKK_PP_1
# # DataGenerator <MKK_TOT>
# __var__MKK_PP = np.empty(shape=task1.shape, dtype=object)
# for __index__, __item__ in np.ndenumerate(task1):
#     __var__MKK_PP[__index__] = __item__['[MKK_PP]']
# MKK_TOT = __var__MKK + __var__MKK_P + __var__MKK_PP
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot1>
# _engine = te.getPlottingEngine()
# tefig = _engine.newFigure(title='plot1 (Steady State Scan (Boris 2D))', xtitle='J4_KK5_1 (J4_KK5)')
#
# for __index__, __xitem__ in np.ndenumerate(J4_KK5_1):
#     __yitem__ = MKK_1[__index__]
#     extra_args = {}
#     if __index__ == 0:
#         extra_args['name'] = 'MKK_1 (MKK)'
#     extra_args['marker'] = 'o'
#     print(__xitem__, '~', __yitem__)
#     tefig.addXYDataset(__xitem__, __yitem__, color='C0', tag='tag0', **extra_args)
# for __index__, __xitem__ in np.ndenumerate(J4_KK5_1):
#     __yitem__ = MKK_P_1[__index__]
#     extra_args = {}
#     if __index__ == 0:
#         extra_args['name'] = 'MKK_P_1 (MKK_P)'
#     extra_args['marker'] = 'o'
#     print(__xitem__, '~', __yitem__)
#     tefig.addXYDataset(__xitem__, __yitem__, color='C1', tag='tag1', **extra_args)
# fig = tefig.render()
#
# if str(_engine) == '<MatplotlibEngine>':
#     filename = os.path.join('./__tellurium__', 'plot1.pdf')
#     fig.savefig(filename, format='pdf', bbox_inches='tight')
#     print('Figure plot1: {}'.format(filename))
#
# # Output <plot2>
# _engine = te.getPlottingEngine()
# tefig = _engine.newFigure(title='plot2 (MKK_TOT vs J4_KK5)', xtitle='J4_KK5_1 (J4_KK5)')
#
# for __index__, __xitem__ in np.ndenumerate(J4_KK5_1):
#     __yitem__ = MKK_TOT[__index__]
#     extra_args = {}
#     if __index__ == 0:
#         extra_args['name'] = 'MKK_TOT (MKK_TOT)'
#     extra_args['marker'] = 'o'
#     print(__xitem__, '~', __yitem__)
#     tefig.addXYDataset(__xitem__, __yitem__, color='C0', tag='tag0', **extra_args)
# fig = tefig.render()
#
# if str(_engine) == '<MatplotlibEngine>':
#     filename = os.path.join('./__tellurium__', 'plot2.pdf')
#     fig.savefig(filename, format='pdf', bbox_inches='tight')
#     print('Figure plot2: {}'.format(filename))
#
# # Output <report1>
# __dfs__report1 = []
# for k in range(J4_KK5_1.shape[1]):
#     __df__k = pandas.DataFrame(np.column_stack([J4_KK5_1[:,k], J1_KK2_1[:,k], MKK_1[:,k], MKK_P_1[:,k], MKK_PP_1[:,k], MKK_TOT[:,k]]),
#     columns=['J4_KK5', 'J1_KK2', 'MKK', 'MKK_P', 'MKK_PP_1', 'MKK_TOT'])
#     __dfs__report1.append(__df__k)
#     te.setLastReport(__df__k)
#     filename = os.path.join('./__tellurium__', 'report1.csv')
#     __df__k.to_csv(filename, sep=',', index=False)
#     print('Report report1: {}'.format(filename))
# ####################################################################################################
# [ 1.] ~ [ 115.0936405]
# [ 1.39] ~ [ 124.70210207]
# [ 1.78] ~ [ 134.09896061]
# [ 2.17] ~ [ 143.08211392]
# [ 2.56] ~ [ 151.51337747]
# [ 2.95] ~ [ 159.31907506]
# [ 3.34] ~ [ 166.47805202]
# [ 3.73] ~ [ 173.00560577]
# [ 4.12] ~ [ 178.93888799]
# [ 4.51] ~ [ 184.32593672]
# [ 4.9] ~ [ 189.21839448]
# [ 5.29] ~ [ 193.66713387]
# [ 5.68] ~ [ 197.71989499]
# [ 6.07] ~ [ 201.4202019]
# [ 6.46] ~ [ 204.80703924]
# [ 6.85] ~ [ 207.91495076]
# [ 7.24] ~ [ 210.77435106]
# [ 7.63] ~ [ 213.41192764]
# [ 8.02] ~ [ 215.85106389]
# [ 8.41] ~ [ 218.11224636]
# [ 8.8] ~ [ 220.2134388]
# [ 9.19] ~ [ 222.17041609]
# [ 9.58] ~ [ 223.9970574]
# [ 9.97] ~ [ 225.70560085]
# [ 10.36] ~ [ 227.30686318]
# [ 10.75] ~ [ 228.81042855]
# [ 11.14] ~ [ 230.2248106]
# [ 11.53] ~ [ 231.5575913]
# [ 11.92] ~ [ 232.81554002]
# [ 12.31] ~ [ 234.00471582]
# [ 12.7] ~ [ 235.13055528]
# [ 13.09] ~ [ 236.19794822]
# [ 13.48] ~ [ 237.21130293]
# [ 13.87] ~ [ 238.17460265]
# [ 14.26] ~ [ 239.09145453]
# [ 14.65] ~ [ 239.96513207]
# [ 15.04] ~ [ 240.79861215]
# [ 15.43] ~ [ 241.5946086]
# [ 15.82] ~ [ 242.35559511]
# [ 16.21] ~ [ 243.08383832]
# [ 16.6] ~ [ 243.78141379]
# [ 16.99] ~ [ 244.45022674]
# [ 17.38] ~ [ 245.09202892]
# [ 17.77] ~ [ 245.70843362]
# [ 18.16] ~ [ 246.30092893]
# [ 18.55] ~ [ 246.87088956]
# [ 18.94] ~ [ 247.4195873]
# [ 19.33] ~ [ 247.94820045]
# [ 19.72] ~ [ 248.45782215]
# [ 20.11] ~ [ 248.9494679]
# [ 20.5] ~ [ 249.42408227]
# [ 20.89] ~ [ 249.88254496]
# [ 21.28] ~ [ 250.32567625]
# [ 21.67] ~ [ 250.75424188]
# [ 22.06] ~ [ 251.16895749]
# [ 22.45] ~ [ 251.57049268]
# [ 22.84] ~ [ 251.95947454]
# [ 23.23] ~ [ 252.33649107]
# [ 23.62] ~ [ 252.70209408]
# [ 24.01] ~ [ 253.05680194]
# [ 24.4] ~ [ 253.40110212]
# [ 24.79] ~ [ 253.73545338]
# [ 25.18] ~ [ 254.06028789]
# [ 25.57] ~ [ 254.37601309]
# [ 25.96] ~ [ 254.68301348]
# [ 26.35] ~ [ 254.98165216]
# [ 26.74] ~ [ 255.27227232]
# [ 27.13] ~ [ 255.55519858]
# [ 27.52] ~ [ 255.83073821]
# [ 27.91] ~ [ 256.09918232]
# [ 28.3] ~ [ 256.36080683]
# [ 28.69] ~ [ 256.61587352]
# [ 29.08] ~ [ 256.86463088]
# [ 29.47] ~ [ 257.10731498]
# [ 29.86] ~ [ 257.34415018]
# [ 30.25] ~ [ 257.57534989]
# [ 30.64] ~ [ 257.80111724]
# [ 31.03] ~ [ 258.02164563]
# [ 31.42] ~ [ 258.23711938]
# [ 31.81] ~ [ 258.44771421]
# [ 32.2] ~ [ 258.65359773]
# [ 32.59] ~ [ 258.85492996]
# [ 32.98] ~ [ 259.05186367]
# [ 33.37] ~ [ 259.24454487]
# [ 33.76] ~ [ 259.43311311]
# [ 34.15] ~ [ 259.6177019]
# [ 34.54] ~ [ 259.79843896]
# [ 34.93] ~ [ 259.9754466]
# [ 35.32] ~ [ 260.14884196]
# [ 35.71] ~ [ 260.31873729]
# [ 36.1] ~ [ 260.48524022]
# [ 36.49] ~ [ 260.64845396]
# [ 36.88] ~ [ 260.80847758]
# [ 37.27] ~ [ 260.96540615]
# [ 37.66] ~ [ 261.119331]
# [ 38.05] ~ [ 261.27033984]
# [ 38.44] ~ [ 261.41851702]
# [ 38.83] ~ [ 261.56394361]
# [ 39.22] ~ [ 261.7066976]
# [ 39.61] ~ [ 261.84685403]
# [ 40.] ~ [ 261.98448515]
# [ 1.] ~ [ 114.5341847]
# [ 1.39] ~ [ 123.96120543]
# [ 1.78] ~ [ 133.19436623]
# [ 2.17] ~ [ 142.03948094]
# [ 2.56] ~ [ 150.36118335]
# [ 2.95] ~ [ 158.08459625]
# [ 3.34] ~ [ 165.18506299]
# [ 3.73] ~ [ 171.67355621]
# [ 4.12] ~ [ 177.58300956]
# [ 4.51] ~ [ 182.95779243]
# [ 4.9] ~ [ 187.84655803]
# [ 5.29] ~ [ 192.29783758]
# [ 5.68] ~ [ 196.35758225]
# [ 6.07] ~ [ 200.06797076]
# [ 6.46] ~ [ 203.46698662]
# [ 6.85] ~ [ 206.58843416]
# [ 7.24] ~ [ 209.46218519]
# [ 7.63] ~ [ 212.11453111]
# [ 8.02] ~ [ 214.5685682]
# [ 8.41] ~ [ 216.84457685]
# [ 8.8] ~ [ 218.96037452]
# [ 9.19] ~ [ 220.93163424]
# [ 9.58] ~ [ 222.77216617]
# [ 9.97] ~ [ 224.49416369]
# [ 10.36] ~ [ 226.1084167]
# [ 10.75] ~ [ 227.62449568]
# [ 11.14] ~ [ 229.05091016]
# [ 11.53] ~ [ 230.39524494]
# [ 11.92] ~ [ 231.66427718]
# [ 12.31] ~ [ 232.8640772]
# [ 12.7] ~ [ 234.00009521]
# [ 13.09] ~ [ 235.07723612]
# [ 13.48] ~ [ 236.09992431]
# [ 13.87] ~ [ 237.0721595]
# [ 14.26] ~ [ 237.99756545]
# [ 14.65] ~ [ 238.87943213]
# [ 15.04] ~ [ 239.72075259]
# [ 15.43] ~ [ 240.52425645]
# [ 15.82] ~ [ 241.29243255]
# [ 16.21] ~ [ 242.0275622]
# [ 16.6] ~ [ 242.73173505]
# [ 16.99] ~ [ 243.40686974]
# [ 17.38] ~ [ 244.05473084]
# [ 17.77] ~ [ 244.67694384]
# [ 18.16] ~ [ 245.27500846]
# [ 18.55] ~ [ 245.85031042]
# [ 18.94] ~ [ 246.40413199]
# [ 19.33] ~ [ 246.9376614]
# [ 19.72] ~ [ 247.45200121]
# [ 20.11] ~ [ 247.94817584]
# [ 20.5] ~ [ 248.42713831]
# [ 20.89] ~ [ 248.88977636]
# [ 21.28] ~ [ 249.33691785]
# [ 21.67] ~ [ 249.76933573]
# [ 22.06] ~ [ 250.18775248]
# [ 22.45] ~ [ 250.59284415]
# [ 22.84] ~ [ 250.985244]
# [ 23.23] ~ [ 251.36554584]
# [ 23.62] ~ [ 251.734307]
# [ 24.01] ~ [ 252.09205114]
# [ 24.4] ~ [ 252.43927068]
# [ 24.79] ~ [ 252.77642913]
# [ 25.18] ~ [ 253.10396316]
# [ 25.57] ~ [ 253.42228449]
# [ 25.96] ~ [ 253.7317817]
# [ 26.35] ~ [ 254.03282176]
# [ 26.74] ~ [ 254.32575155]
# [ 27.13] ~ [ 254.61089919]
# [ 27.52] ~ [ 254.88857532]
# [ 27.91] ~ [ 255.15907422]
# [ 28.3] ~ [ 255.42267487]
# [ 28.69] ~ [ 255.67964194]
# [ 29.08] ~ [ 255.9302267]
# [ 29.47] ~ [ 256.17466785]
# [ 29.86] ~ [ 256.41319228]
# [ 30.25] ~ [ 256.64601583]
# [ 30.64] ~ [ 256.87334392]
# [ 31.03] ~ [ 257.09537216]
# [ 31.42] ~ [ 257.31228698]
# [ 31.81] ~ [ 257.52426612]
# [ 32.2] ~ [ 257.73147913]
# [ 32.59] ~ [ 257.93408787]
# [ 32.98] ~ [ 258.13224691]
# [ 33.37] ~ [ 258.32610393]
# [ 33.76] ~ [ 258.51580013]
# [ 34.15] ~ [ 258.70147058]
# [ 34.54] ~ [ 258.88324451]
# [ 34.93] ~ [ 259.06124565]
# [ 35.32] ~ [ 259.23559255]
# [ 35.71] ~ [ 259.40639877]
# [ 36.1] ~ [ 259.57377322]
# [ 36.49] ~ [ 259.73782036]
# [ 36.88] ~ [ 259.89864041]
# [ 37.27] ~ [ 260.05632959]
# [ 37.66] ~ [ 260.21098031]
# [ 38.05] ~ [ 260.36268136]
# [ 38.44] ~ [ 260.51151807]
# [ 38.83] ~ [ 260.6575725]
# [ 39.22] ~ [ 260.80092358]
# [ 39.61] ~ [ 260.94164726]
# [ 40.] ~ [ 261.07981665]
# [ 1.] ~ [ 113.92581961]
# [ 1.39] ~ [ 123.15688801]
# [ 1.78] ~ [ 132.21252723]
# [ 2.17] ~ [ 140.9070299]
# [ 2.56] ~ [ 149.10828395]
# [ 2.95] ~ [ 156.7404378]
# [ 3.34] ~ [ 163.77534544]
# [ 3.73] ~ [ 170.21950803]
# [ 4.12] ~ [ 176.101407]
# [ 4.51] ~ [ 181.46148117]
# [ 4.9] ~ [ 186.34514257]
# [ 5.29] ~ [ 190.79835855]
# [ 5.68] ~ [ 194.86510448]
# [ 6.07] ~ [ 198.58606192]
# [ 6.46] ~ [ 201.99809254]
# [ 6.85] ~ [ 205.13416664]
# [ 7.24] ~ [ 208.02353984]
# [ 7.63] ~ [ 210.69205087]
# [ 8.02] ~ [ 213.16246569]
# [ 8.41] ~ [ 215.45482548]
# [ 8.8] ~ [ 217.58677651]
# [ 9.19] ~ [ 219.57387111]
# [ 9.58] ~ [ 221.42983641]
# [ 9.97] ~ [ 223.16681068]
# [ 10.36] ~ [ 224.79554941]
# [ 10.75] ~ [ 226.325604]
# [ 11.14] ~ [ 227.76547614]
# [ 11.53] ~ [ 229.12275102]
# [ 11.92] ~ [ 230.40421212]
# [ 12.31] ~ [ 231.61594026]
# [ 12.7] ~ [ 232.76339909]
# [ 13.09] ~ [ 233.85150892]
# [ 13.48] ~ [ 234.8847107]
# [ 13.87] ~ [ 235.86702148]
# [ 14.26] ~ [ 236.80208255]
# [ 14.65] ~ [ 237.69320145]
# [ 15.04] ~ [ 238.54338853]
# [ 15.43] ~ [ 239.35539036]
# [ 15.82] ~ [ 240.13171217]
# [ 16.21] ~ [ 240.87465117]
# [ 16.6] ~ [ 241.58631225]
# [ 16.99] ~ [ 242.26862869]
# [ 17.38] ~ [ 242.92337904]
# [ 17.77] ~ [ 243.55220214]
# [ 18.16] ~ [ 244.1566104]
# [ 18.55] ~ [ 244.73800162]
# [ 18.94] ~ [ 245.29766957]
# [ 19.33] ~ [ 245.83681338]
# [ 19.72] ~ [ 246.35654597]
# [ 20.11] ~ [ 246.85790157]
# [ 20.5] ~ [ 247.34184255]
# [ 20.89] ~ [ 247.80926547]
# [ 21.28] ~ [ 248.26100659]
# [ 21.67] ~ [ 248.6978468]
# [ 22.06] ~ [ 249.12051614]
# [ 22.45] ~ [ 249.52969782]
# [ 22.84] ~ [ 249.92603189]
# [ 23.23] ~ [ 250.31011862]
# [ 23.62] ~ [ 250.68252147]
# [ 24.01] ~ [ 251.0437699]
# [ 24.4] ~ [ 251.39436188]
# [ 24.79] ~ [ 251.73476616]
# [ 25.18] ~ [ 252.06542442]
# [ 25.57] ~ [ 252.38675314]
# [ 25.96] ~ [ 252.6991454]
# [ 26.35] ~ [ 253.00297249]
# [ 26.74] ~ [ 253.29858539]
# [ 27.13] ~ [ 253.58631614]
# [ 27.52] ~ [ 253.86647909]
# [ 27.91] ~ [ 254.13937206]
# [ 28.3] ~ [ 254.40527744]
# [ 28.69] ~ [ 254.66446312]
# [ 29.08] ~ [ 254.91718346]
# [ 29.47] ~ [ 255.16368011]
# [ 29.86] ~ [ 255.40418277]
# [ 30.25] ~ [ 255.63890997]
# [ 30.64] ~ [ 255.8680697]
# [ 31.03] ~ [ 256.09186005]
# [ 31.42] ~ [ 256.3104698]
# [ 31.81] ~ [ 256.52407892]
# [ 32.2] ~ [ 256.73285916]
# [ 32.59] ~ [ 256.93697442]
# [ 32.98] ~ [ 257.13658125]
# [ 33.37] ~ [ 257.33182926]
# [ 33.76] ~ [ 257.52286146]
# [ 34.15] ~ [ 257.70981465]
# [ 34.54] ~ [ 257.89281976]
# [ 34.93] ~ [ 258.07200215]
# [ 35.32] ~ [ 258.24748187]
# [ 35.71] ~ [ 258.41937401]
# [ 36.1] ~ [ 258.5877889]
# [ 36.49] ~ [ 258.75283235]
# [ 36.88] ~ [ 258.91460594]
# [ 37.27] ~ [ 259.07320714]
# [ 37.66] ~ [ 259.2287296]
# [ 38.05] ~ [ 259.38126327]
# [ 38.44] ~ [ 259.53089462]
# [ 38.83] ~ [ 259.67770682]
# [ 39.22] ~ [ 259.82177983]
# [ 39.61] ~ [ 259.96319063]
# [ 40.] ~ [ 260.1020133]
# [ 1.] ~ [ 109.56097543]
# [ 1.39] ~ [ 117.36309889]
# [ 1.78] ~ [ 125.06855935]
# [ 2.17] ~ [ 132.55301637]
# [ 2.56] ~ [ 139.71830632]
# [ 2.95] ~ [ 146.49684486]
# [ 3.34] ~ [ 152.85029394]
# [ 3.73] ~ [ 158.76468814]
# [ 4.12] ~ [ 164.24426989]
# [ 4.51] ~ [ 169.30559332]
# [ 4.9] ~ [ 173.97266351]
# [ 5.29] ~ [ 178.27330493]
# [ 5.68] ~ [ 182.23664499]
# [ 6.07] ~ [ 185.89148379]
# [ 6.46] ~ [ 189.26531309]
# [ 6.85] ~ [ 192.38378391]
# [ 7.24] ~ [ 195.27047001]
# [ 7.63] ~ [ 197.94681793]
# [ 8.02] ~ [ 200.43220859]
# [ 8.41] ~ [ 202.7440809]
# [ 8.8] ~ [ 204.89808552]
# [ 9.19] ~ [ 206.90824898]
# [ 9.58] ~ [ 208.78713619]
# [ 9.97] ~ [ 210.54600479]
# [ 10.36] ~ [ 212.19494782]
# [ 10.75] ~ [ 213.74302334]
# [ 11.14] ~ [ 215.19837085]
# [ 11.53] ~ [ 216.56831506]
# [ 11.92] ~ [ 217.85945782]
# [ 12.31] ~ [ 219.07775936]
# [ 12.7] ~ [ 220.22860984]
# [ 13.09] ~ [ 221.31689242]
# [ 13.48] ~ [ 222.34703868]
# [ 13.87] ~ [ 223.32307746]
# [ 14.26] ~ [ 224.24867781]
# [ 14.65] ~ [ 225.12718687]
# [ 15.04] ~ [ 225.96166327]
# [ 15.43] ~ [ 226.75490667]
# [ 15.82] ~ [ 227.50948513]
# [ 16.21] ~ [ 228.22775279]
# [ 16.6] ~ [ 228.91187883]
# [ 16.99] ~ [ 229.56385988]
# [ 17.38] ~ [ 230.18553771]
# [ 17.77] ~ [ 230.77861369]
# [ 18.16] ~ [ 231.34466172]
# [ 18.55] ~ [ 231.88513974]
# [ 18.94] ~ [ 232.40140008]
# [ 19.33] ~ [ 232.89469872]
# [ 19.72] ~ [ 233.36620364]
# [ 20.11] ~ [ 233.81700231]
# [ 20.5] ~ [ 234.24810844]
# [ 20.89] ~ [ 234.66046812]
# [ 21.28] ~ [ 235.05496529]
# [ 21.67] ~ [ 235.43242675]
# [ 22.06] ~ [ 235.79362672]
# [ 22.45] ~ [ 236.13929089]
# [ 22.84] ~ [ 236.47010022]
# [ 23.23] ~ [ 236.78669432]
# [ 23.62] ~ [ 237.08967453]
# [ 24.01] ~ [ 237.37960678]
# [ 24.4] ~ [ 237.65702419]
# [ 24.79] ~ [ 237.92242938]
# [ 25.18] ~ [ 238.17629669]
# [ 25.57] ~ [ 238.41907417]
# [ 25.96] ~ [ 238.65118538]
# [ 26.35] ~ [ 238.87303107]
# [ 26.74] ~ [ 239.08499073]
# [ 27.13] ~ [ 239.28742404]
# [ 27.52] ~ [ 239.48067213]
# [ 27.91] ~ [ 239.66505882]
# [ 28.3] ~ [ 239.84089175]
# [ 28.69] ~ [ 240.00846337]
# [ 29.08] ~ [ 240.16805194]
# [ 29.47] ~ [ 240.3199224]
# [ 29.86] ~ [ 240.46432718]
# [ 30.25] ~ [ 240.60150699]
# [ 30.64] ~ [ 240.73169147]
# [ 31.03] ~ [ 240.85509992]
# [ 31.42] ~ [ 240.97194187]
# [ 31.81] ~ [ 241.08241764]
# [ 32.2] ~ [ 241.18671891]
# [ 32.59] ~ [ 241.28502916]
# [ 32.98] ~ [ 241.37752418]
# [ 33.37] ~ [ 241.46437247]
# [ 33.76] ~ [ 241.54573565]
# [ 34.15] ~ [ 241.62176883]
# [ 34.54] ~ [ 241.69262098]
# [ 34.93] ~ [ 241.75843523]
# [ 35.32] ~ [ 241.81934918]
# [ 35.71] ~ [ 241.87549522]
# [ 36.1] ~ [ 241.92700076]
# [ 36.49] ~ [ 241.9739885]
# [ 36.88] ~ [ 242.01657667]
# [ 37.27] ~ [ 242.05487925]
# [ 37.66] ~ [ 242.08900616]
# [ 38.05] ~ [ 242.1190635]
# [ 38.44] ~ [ 242.1451537]
# [ 38.83] ~ [ 242.16737567]
# [ 39.22] ~ [ 242.18582503]
# [ 39.61] ~ [ 242.20059423]
# [ 40.] ~ [ 242.21177266]
# [ 1.] ~ [ 107.854218]
# [ 1.39] ~ [ 115.0707553]
# [ 1.78] ~ [ 122.18816568]
# [ 2.17] ~ [ 129.10520073]
# [ 2.56] ~ [ 135.74093296]
# [ 2.95] ~ [ 142.03801498]
# [ 3.34] ~ [ 147.96197935]
# [ 3.73] ~ [ 153.49794939]
# [ 4.12] ~ [ 158.64623708]
# [ 4.51] ~ [ 163.41793096]
# [ 4.9] ~ [ 167.83108802]
# [ 5.29] ~ [ 171.90775168]
# [ 5.68] ~ [ 175.6717798]
# [ 6.07] ~ [ 179.1473567]
# [ 6.46] ~ [ 182.35803391]
# [ 6.85] ~ [ 185.3261556]
# [ 7.24] ~ [ 188.07255123]
# [ 7.63] ~ [ 190.61640642]
# [ 8.02] ~ [ 192.97524813]
# [ 8.41] ~ [ 195.16499927]
# [ 8.8] ~ [ 197.20007291]
# [ 9.19] ~ [ 199.09348614]
# [ 9.58] ~ [ 200.85698093]
# [ 9.97] ~ [ 202.50114427]
# [ 10.36] ~ [ 204.0355229]
# [ 10.75] ~ [ 205.46873031]
# [ 11.14] ~ [ 206.80854475]
# [ 11.53] ~ [ 208.06199808]
# [ 11.92] ~ [ 209.23545559]
# [ 12.31] ~ [ 210.33468746]
# [ 12.7] ~ [ 211.36493236]
# [ 13.09] ~ [ 212.33095391]
# [ 13.48] ~ [ 213.23709091]
# [ 13.87] ~ [ 214.08730174]
# [ 14.26] ~ [ 214.88520379]
# [ 14.65] ~ [ 215.63410836]
# [ 15.04] ~ [ 216.33705313]
# [ 15.43] ~ [ 216.99682354]
# [ 15.82] ~ [ 217.61598665]
# [ 16.21] ~ [ 218.19690633]
# [ 16.6] ~ [ 218.74176427]
# [ 16.99] ~ [ 219.2525772]
# [ 17.38] ~ [ 219.73121223]
# [ 17.77] ~ [ 220.17940064]
# [ 18.16] ~ [ 220.59875008]
# [ 18.55] ~ [ 220.99075563]
# [ 18.94] ~ [ 221.35680965]
# [ 19.33] ~ [ 221.69821062]
# [ 19.72] ~ [ 222.01617116]
# [ 20.11] ~ [ 222.31182519]
# [ 20.5] ~ [ 222.58623438]
# [ 20.89] ~ [ 222.84039404]
# [ 21.28] ~ [ 223.07523837]
# [ 21.67] ~ [ 223.29164529]
# [ 22.06] ~ [ 223.49044074]
# [ 22.45] ~ [ 223.67240262]
# [ 22.84] ~ [ 223.83826442]
# [ 23.23] ~ [ 223.98871841]
# [ 23.62] ~ [ 224.12441867]
# [ 24.01] ~ [ 224.24598374]
# [ 24.4] ~ [ 224.35399914]
# [ 24.79] ~ [ 224.44901962]
# [ 25.18] ~ [ 224.53157123]
# [ 25.57] ~ [ 224.6021532]
# [ 25.96] ~ [ 224.66123973]
# [ 26.35] ~ [ 224.70928153]
# [ 26.74] ~ [ 224.74670737]
# [ 27.13] ~ [ 224.77392538]
# [ 27.52] ~ [ 224.79132433]
# [ 27.91] ~ [ 224.79927479]
# [ 28.3] ~ [ 224.79813019]
# [ 28.69] ~ [ 224.78822782]
# [ 29.08] ~ [ 224.76988976]
# [ 29.47] ~ [ 224.74342373]
# [ 29.86] ~ [ 224.70912385]
# [ 30.25] ~ [ 224.66727146]
# [ 30.64] ~ [ 224.61813571]
# [ 31.03] ~ [ 224.56197428]
# [ 31.42] ~ [ 224.49903396]
# [ 31.81] ~ [ 224.42955117]
# [ 32.2] ~ [ 224.35375255]
# [ 32.59] ~ [ 224.27185541]
# [ 32.98] ~ [ 224.1840682]
# [ 33.37] ~ [ 224.09059095]
# [ 33.76] ~ [ 223.99161567]
# [ 34.15] ~ [ 223.88732675]
# [ 34.54] ~ [ 223.77790129]
# [ 34.93] ~ [ 223.66350948]
# [ 35.32] ~ [ 223.54431488]
# [ 35.71] ~ [ 223.42047475]
# [ 36.1] ~ [ 223.29214034]
# [ 36.49] ~ [ 223.15945713]
# [ 36.88] ~ [ 223.02256513]
# [ 37.27] ~ [ 222.88159909]
# [ 37.66] ~ [ 222.73668872]
# [ 38.05] ~ [ 222.58795896]
# [ 38.44] ~ [ 222.43553014]
# [ 38.83] ~ [ 222.2795182]
# [ 39.22] ~ [ 222.12003486]
# [ 39.61] ~ [ 221.9571878]
# [ 40.] ~ [ 221.79108086]
# [ 1.] ~ [ 105.21600459]
# [ 1.39] ~ [ 111.51171625]
# [ 1.78] ~ [ 117.67417751]
# [ 2.17] ~ [ 123.63275087]
# [ 2.56] ~ [ 129.33201079]
# [ 2.95] ~ [ 134.73294049]
# [ 3.34] ~ [ 139.81203957]
# [ 3.73] ~ [ 144.55910279]
# [ 4.12] ~ [ 148.97442685]
# [ 4.51] ~ [ 153.06601198]
# [ 4.9] ~ [ 156.84709133]
# [ 5.29] ~ [ 160.33412727]
# [ 5.68] ~ [ 163.54528682]
# [ 6.07] ~ [ 166.49934198]
# [ 6.46] ~ [ 169.21491531]
# [ 6.85] ~ [ 171.70999022]
# [ 7.24] ~ [ 174.00161541]
# [ 7.63] ~ [ 176.10574647]
# [ 8.02] ~ [ 178.0371814]
# [ 8.41] ~ [ 179.80955789]
# [ 8.8] ~ [ 181.43538971]
# [ 9.19] ~ [ 182.92612619]
# [ 9.58] ~ [ 184.29222393]
# [ 9.97] ~ [ 185.54322358]
# [ 10.36] ~ [ 186.68782704]
# [ 10.75] ~ [ 187.73397208]
# [ 11.14] ~ [ 188.68890289]
# [ 11.53] ~ [ 189.55923555]
# [ 11.92] ~ [ 190.35101804]
# [ 12.31] ~ [ 191.06978494]
# [ 12.7] ~ [ 191.72060689]
# [ 13.09] ~ [ 192.30813512]
# [ 13.48] ~ [ 192.83664154]
# [ 13.87] ~ [ 193.31005463]
# [ 14.26] ~ [ 193.73199162]
# [ 14.65] ~ [ 194.10578738]
# [ 15.04] ~ [ 194.43452017]
# [ 15.43] ~ [ 194.72103491]
# [ 15.82] ~ [ 194.96796387]
# [ 16.21] ~ [ 195.17774534]
# [ 16.6] ~ [ 195.35264044]
# [ 16.99] ~ [ 195.49474822]
# [ 17.38] ~ [ 195.60601921]
# [ 17.77] ~ [ 195.6882678]
# [ 18.16] ~ [ 195.74318329]
# [ 18.55] ~ [ 195.77233997]
# [ 18.94] ~ [ 195.77720628]
# [ 19.33] ~ [ 195.75915305]
# [ 19.72] ~ [ 195.71946109]
# [ 20.11] ~ [ 195.65932804]
# [ 20.5] ~ [ 195.57987464]
# [ 20.89] ~ [ 195.48215045]
# [ 21.28] ~ [ 195.36713913]
# [ 21.67] ~ [ 195.23576318]
# [ 22.06] ~ [ 195.08888838]
# [ 22.45] ~ [ 194.92732783]
# [ 22.84] ~ [ 194.75184563]
# [ 23.23] ~ [ 194.56316035]
# [ 23.62] ~ [ 194.36194812]
# [ 24.01] ~ [ 194.14884554]
# [ 24.4] ~ [ 193.92445246]
# [ 24.79] ~ [ 193.68933426]
# [ 25.18] ~ [ 193.44402431]
# [ 25.57] ~ [ 193.18902595]
# [ 25.96] ~ [ 192.92481458]
# [ 26.35] ~ [ 192.65183936]
# [ 26.74] ~ [ 192.37052494]
# [ 27.13] ~ [ 192.08127303]
# [ 27.52] ~ [ 191.78446382]
# [ 27.91] ~ [ 191.48045734]
# [ 28.3] ~ [ 191.16959471]
# [ 28.69] ~ [ 190.85219929]
# [ 29.08] ~ [ 190.5285778]
# [ 29.47] ~ [ 190.19902128]
# [ 29.86] ~ [ 189.86380607]
# [ 30.25] ~ [ 189.52319464]
# [ 30.64] ~ [ 189.17743648]
# [ 31.03] ~ [ 188.82676879]
# [ 31.42] ~ [ 188.47141722]
# [ 31.81] ~ [ 188.11159656]
# [ 32.2] ~ [ 187.74751133]
# [ 32.59] ~ [ 187.37935636]
# [ 32.98] ~ [ 187.00731737]
# [ 33.37] ~ [ 186.63157145]
# [ 33.76] ~ [ 186.25228753]
# [ 34.15] ~ [ 185.86962688]
# [ 34.54] ~ [ 185.48374345]
# [ 34.93] ~ [ 185.09478433]
# [ 35.32] ~ [ 184.70289012]
# [ 35.71] ~ [ 184.30819521]
# [ 36.1] ~ [ 183.91082817]
# [ 36.49] ~ [ 183.51091206]
# [ 36.88] ~ [ 183.10856465]
# [ 37.27] ~ [ 182.70389878]
# [ 37.66] ~ [ 182.29702253]
# [ 38.05] ~ [ 181.88803953]
# [ 38.44] ~ [ 181.47704917]
# [ 38.83] ~ [ 181.06414676]
# [ 39.22] ~ [ 180.64942379]
# [ 39.61] ~ [ 180.23296812]
# [ 40.] ~ [ 179.8148641]
# [ 1.] ~ [ 100.28095969]
# [ 1.39] ~ [ 104.88861889]
# [ 1.78] ~ [ 109.25585966]
# [ 2.17] ~ [ 113.35326347]
# [ 2.56] ~ [ 117.16280849]
# [ 2.95] ~ [ 120.6764993]
# [ 3.34] ~ [ 123.89455142]
# [ 3.73] ~ [ 126.82348045]
# [ 4.12] ~ [ 129.47432691]
# [ 4.51] ~ [ 131.861138]
# [ 4.9] ~ [ 133.99974613]
# [ 5.29] ~ [ 135.90683358]
# [ 5.68] ~ [ 137.59924689]
# [ 6.07] ~ [ 139.09351591]
# [ 6.46] ~ [ 140.40553291]
# [ 6.85] ~ [ 141.55035254]
# [ 7.24] ~ [ 142.54208047]
# [ 7.63] ~ [ 143.39382503]
# [ 8.02] ~ [ 144.11769273]
# [ 8.41] ~ [ 144.72481289]
# [ 8.8] ~ [ 145.22538094]
# [ 9.19] ~ [ 145.62871282]
# [ 9.58] ~ [ 145.94330507]
# [ 9.97] ~ [ 146.17689689]
# [ 10.36] ~ [ 146.33653176]
# [ 10.75] ~ [ 146.42861704]
# [ 11.14] ~ [ 146.45898037]
# [ 11.53] ~ [ 146.43292253]
# [ 11.92] ~ [ 146.35526634]
# [ 12.31] ~ [ 146.23040166]
# [ 12.7] ~ [ 146.06232649]
# [ 13.09] ~ [ 145.85468437]
# [ 13.48] ~ [ 145.61079831]
# [ 13.87] ~ [ 145.33370149]
# [ 14.26] ~ [ 145.02616492]
# [ 14.65] ~ [ 144.69072248]
# [ 15.04] ~ [ 144.32969341]
# [ 15.43] ~ [ 143.9452025]
# [ 15.82] ~ [ 143.5391984]
# [ 16.21] ~ [ 143.11346995]
# [ 16.6] ~ [ 142.66966095]
# [ 16.99] ~ [ 142.20928346]
# [ 17.38] ~ [ 141.73372968]
# [ 17.77] ~ [ 141.2442828]
# [ 18.16] ~ [ 140.74212661]
# [ 18.55] ~ [ 140.22835432]
# [ 18.94] ~ [ 139.70397638]
# [ 19.33] ~ [ 139.16992768]
# [ 19.72] ~ [ 138.62707391]
# [ 20.11] ~ [ 138.07621747]
# [ 20.5] ~ [ 137.51810267]
# [ 20.89] ~ [ 136.95342055]
# [ 21.28] ~ [ 136.38281321]
# [ 21.67] ~ [ 135.80687772]
# [ 22.06] ~ [ 135.22616973]
# [ 22.45] ~ [ 134.64120673]
# [ 22.84] ~ [ 134.05247096]
# [ 23.23] ~ [ 133.46041215]
# [ 23.62] ~ [ 132.86544997]
# [ 24.01] ~ [ 132.26797634]
# [ 24.4] ~ [ 131.66835737]
# [ 24.79] ~ [ 131.0669353]
# [ 25.18] ~ [ 130.46403026]
# [ 25.57] ~ [ 129.8599418]
# [ 25.96] ~ [ 129.25495035]
# [ 26.35] ~ [ 128.64931856]
# [ 26.74] ~ [ 128.04329253]
# [ 27.13] ~ [ 127.43710292]
# [ 27.52] ~ [ 126.83096598]
# [ 27.91] ~ [ 126.22508456]
# [ 28.3] ~ [ 125.61964892]
# [ 28.69] ~ [ 125.01483758]
# [ 29.08] ~ [ 124.41081811]
# [ 29.47] ~ [ 123.80774774]
# [ 29.86] ~ [ 123.20577411]
# [ 30.25] ~ [ 122.60503577]
# [ 30.64] ~ [ 122.00566282]
# [ 31.03] ~ [ 121.40777737]
# [ 31.42] ~ [ 120.81149402]
# [ 31.81] ~ [ 120.21692037]
# [ 32.2] ~ [ 119.62415734]
# [ 32.59] ~ [ 119.03329963]
# [ 32.98] ~ [ 118.44443604]
# [ 33.37] ~ [ 117.85764984]
# [ 33.76] ~ [ 117.27301904]
# [ 34.15] ~ [ 116.69061675]
# [ 34.54] ~ [ 116.11051135]
# [ 34.93] ~ [ 115.53276687]
# [ 35.32] ~ [ 114.95744313]
# [ 35.71] ~ [ 114.38459602]
# [ 36.1] ~ [ 113.8142777]
# [ 36.49] ~ [ 113.2465368]
# [ 36.88] ~ [ 112.68141857]
# [ 37.27] ~ [ 112.11896512]
# [ 37.66] ~ [ 111.55921555]
# [ 38.05] ~ [ 111.00220608]
# [ 38.44] ~ [ 110.44797025]
# [ 38.83] ~ [ 109.89653902]
# [ 39.22] ~ [ 109.3479409]
# [ 39.61] ~ [ 108.8022021]
# [ 40.] ~ [ 108.25934662]
# [ 1.] ~ [ 87.05399773]
# [ 1.39] ~ [ 88.17413592]
# [ 1.78] ~ [ 89.00233889]
# [ 2.17] ~ [ 89.58077436]
# [ 2.56] ~ [ 89.94829974]
# [ 2.95] ~ [ 90.13935954]
# [ 3.34] ~ [ 90.18372035]
# [ 3.73] ~ [ 90.1066816]
# [ 4.12] ~ [ 89.92951721]
# [ 4.51] ~ [ 89.66999856]
# [ 4.9] ~ [ 89.34291571]
# [ 5.29] ~ [ 88.96055584]
# [ 5.68] ~ [ 88.53312269]
# [ 6.07] ~ [ 88.0690942]
# [ 6.46] ~ [ 87.57552217]
# [ 6.85] ~ [ 87.05828081]
# [ 7.24] ~ [ 86.52227141]
# [ 7.63] ~ [ 85.97159052]
# [ 8.02] ~ [ 85.40966766]
# [ 8.41] ~ [ 84.83937837]
# [ 8.8] ~ [ 84.26313688]
# [ 9.19] ~ [ 83.68297232]
# [ 9.58] ~ [ 83.10059147]
# [ 9.97] ~ [ 82.51743059]
# [ 10.36] ~ [ 81.93469833]
# [ 10.75] ~ [ 81.35341134]
# [ 11.14] ~ [ 80.77442393]
# [ 11.53] ~ [ 80.19845283]
# [ 11.92] ~ [ 79.62609795]
# [ 12.31] ~ [ 79.05785978]
# [ 12.7] ~ [ 78.49415405]
# [ 13.09] ~ [ 77.93532411]
# [ 13.48] ~ [ 77.38165146]
# [ 13.87] ~ [ 76.83336458]
# [ 14.26] ~ [ 76.29064656]
# [ 14.65] ~ [ 75.75364141]
# [ 15.04] ~ [ 75.22246004]
# [ 15.43] ~ [ 74.69718429]
# [ 15.82] ~ [ 74.17787145]
# [ 16.21] ~ [ 73.66455763]
# [ 16.6] ~ [ 73.15726077]
# [ 16.99] ~ [ 72.65598321]
# [ 17.38] ~ [ 72.16071396]
# [ 17.77] ~ [ 71.67143056]
# [ 18.16] ~ [ 71.18810084]
# [ 18.55] ~ [ 70.71068435]
# [ 18.94] ~ [ 70.23913357]
# [ 19.33] ~ [ 69.77339506]
# [ 19.72] ~ [ 69.3134104]
# [ 20.11] ~ [ 68.85911701]
# [ 20.5] ~ [ 68.41044888]
# [ 20.89] ~ [ 67.96733718]
# [ 21.28] ~ [ 67.52971085]
# [ 21.67] ~ [ 67.09749701]
# [ 22.06] ~ [ 66.67062142]
# [ 22.45] ~ [ 66.24900885]
# [ 22.84] ~ [ 65.83258336]
# [ 23.23] ~ [ 65.42126858]
# [ 23.62] ~ [ 65.01498798]
# [ 24.01] ~ [ 64.61366502]
# [ 24.4] ~ [ 64.21722337]
# [ 24.79] ~ [ 63.82558704]
# [ 25.18] ~ [ 63.43868055]
# [ 25.57] ~ [ 63.05642896]
# [ 25.96] ~ [ 62.67875808]
# [ 26.35] ~ [ 62.30559444]
# [ 26.74] ~ [ 61.93686544]
# [ 27.13] ~ [ 61.57249938]
# [ 27.52] ~ [ 61.21242549]
# [ 27.91] ~ [ 60.856574]
# [ 28.3] ~ [ 60.50487615]
# [ 28.69] ~ [ 60.15726423]
# [ 29.08] ~ [ 59.81367159]
# [ 29.47] ~ [ 59.47403266]
# [ 29.86] ~ [ 59.13828295]
# [ 30.25] ~ [ 58.80635907]
# [ 30.64] ~ [ 58.47819872]
# [ 31.03] ~ [ 58.15374069]
# [ 31.42] ~ [ 57.83292487]
# [ 31.81] ~ [ 57.51569223]
# [ 32.2] ~ [ 57.20198481]
# [ 32.59] ~ [ 56.89174574]
# [ 32.98] ~ [ 56.58491919]
# [ 33.37] ~ [ 56.28145037]
# [ 33.76] ~ [ 55.98128554]
# [ 34.15] ~ [ 55.68437197]
# [ 34.54] ~ [ 55.39065793]
# [ 34.93] ~ [ 55.10009268]
# [ 35.32] ~ [ 54.81262646]
# [ 35.71] ~ [ 54.52821047]
# [ 36.1] ~ [ 54.24679683]
# [ 36.49] ~ [ 53.9683386]
# [ 36.88] ~ [ 53.69278975]
# [ 37.27] ~ [ 53.42010514]
# [ 37.66] ~ [ 53.15024049]
# [ 38.05] ~ [ 52.88315238]
# [ 38.44] ~ [ 52.61879825]
# [ 38.83] ~ [ 52.35713635]
# [ 39.22] ~ [ 52.09812572]
# [ 39.61] ~ [ 51.84172621]
# [ 40.] ~ [ 51.58789845]
# [ 1.] ~ [ 48.63976111]
# [ 1.39] ~ [ 48.20970583]
# [ 1.78] ~ [ 47.79404099]
# [ 2.17] ~ [ 47.39164294]
# [ 2.56] ~ [ 47.00153059]
# [ 2.95] ~ [ 46.62284102]
# [ 3.34] ~ [ 46.25481018]
# [ 3.73] ~ [ 45.8967575]
# [ 4.12] ~ [ 45.54807348]
# [ 4.51] ~ [ 45.20820952]
# [ 4.9] ~ [ 44.87666975]
# [ 5.29] ~ [ 44.55300366]
# [ 5.68] ~ [ 44.23680097]
# [ 6.07] ~ [ 43.92768634]
# [ 6.46] ~ [ 43.62531534]
# [ 6.85] ~ [ 43.32937095]
# [ 7.24] ~ [ 43.03956057]
# [ 7.63] ~ [ 42.75561337]
# [ 8.02] ~ [ 42.4772781]
# [ 8.41] ~ [ 42.20432111]
# [ 8.8] ~ [ 41.93652462]
# [ 9.19] ~ [ 41.67368525]
# [ 9.58] ~ [ 41.4156127]
# [ 9.97] ~ [ 41.16212856]
# [ 10.36] ~ [ 40.9130653]
# [ 10.75] ~ [ 40.66826532]
# [ 11.14] ~ [ 40.42758018]
# [ 11.53] ~ [ 40.19086979]
# [ 11.92] ~ [ 39.95800181]
# [ 12.31] ~ [ 39.72885103]
# [ 12.7] ~ [ 39.50329884]
# [ 13.09] ~ [ 39.28123274]
# [ 13.48] ~ [ 39.06254593]
# [ 13.87] ~ [ 38.84713683]
# [ 14.26] ~ [ 38.63490883]
# [ 14.65] ~ [ 38.42576987]
# [ 15.04] ~ [ 38.21963216]
# [ 15.43] ~ [ 38.01641194]
# [ 15.82] ~ [ 37.81602917]
# [ 16.21] ~ [ 37.61840732]
# [ 16.6] ~ [ 37.42347318]
# [ 16.99] ~ [ 37.23115662]
# [ 17.38] ~ [ 37.04139042]
# [ 17.77] ~ [ 36.85411013]
# [ 18.16] ~ [ 36.66925387]
# [ 18.55] ~ [ 36.4867622]
# [ 18.94] ~ [ 36.30657802]
# [ 19.33] ~ [ 36.12864637]
# [ 19.72] ~ [ 35.9529144]
# [ 20.11] ~ [ 35.7793312]
# [ 20.5] ~ [ 35.60784772]
# [ 20.89] ~ [ 35.43841666]
# [ 21.28] ~ [ 35.27099242]
# [ 21.67] ~ [ 35.10553097]
# [ 22.06] ~ [ 34.94198982]
# [ 22.45] ~ [ 34.78032791]
# [ 22.84] ~ [ 34.62050553]
# [ 23.23] ~ [ 34.46248433]
# [ 23.62] ~ [ 34.30622716]
# [ 24.01] ~ [ 34.1516981]
# [ 24.4] ~ [ 33.99886236]
# [ 24.79] ~ [ 33.84768622]
# [ 25.18] ~ [ 33.69813703]
# [ 25.57] ~ [ 33.55018312]
# [ 25.96] ~ [ 33.40379379]
# [ 26.35] ~ [ 33.25893924]
# [ 26.74] ~ [ 33.11559055]
# [ 27.13] ~ [ 32.97371965]
# [ 27.52] ~ [ 32.83329928]
# [ 27.91] ~ [ 32.69430293]
# [ 28.3] ~ [ 32.55670487]
# [ 28.69] ~ [ 32.42048006]
# [ 29.08] ~ [ 32.28560416]
# [ 29.47] ~ [ 32.15205349]
# [ 29.86] ~ [ 32.019805]
# [ 30.25] ~ [ 31.88883627]
# [ 30.64] ~ [ 31.75912545]
# [ 31.03] ~ [ 31.63065128]
# [ 31.42] ~ [ 31.50339302]
# [ 31.81] ~ [ 31.3773305]
# [ 32.2] ~ [ 31.25244403]
# [ 32.59] ~ [ 31.12871441]
# [ 32.98] ~ [ 31.00612295]
# [ 33.37] ~ [ 30.88465137]
# [ 33.76] ~ [ 30.76428188]
# [ 34.15] ~ [ 30.6449971]
# [ 34.54] ~ [ 30.52678005]
# [ 34.93] ~ [ 30.40961417]
# [ 35.32] ~ [ 30.29348329]
# [ 35.71] ~ [ 30.17837161]
# [ 36.1] ~ [ 30.06426369]
# [ 36.49] ~ [ 29.95114444]
# [ 36.88] ~ [ 29.83899913]
# [ 37.27] ~ [ 29.72781334]
# [ 37.66] ~ [ 29.61757297]
# [ 38.05] ~ [ 29.50826425]
# [ 38.44] ~ [ 29.39987369]
# [ 38.83] ~ [ 29.2923881]
# [ 39.22] ~ [ 29.18579459]
# [ 39.61] ~ [ 29.08008052]
# [ 40.] ~ [ 28.97523353]
# [ 1.] ~ [ 165.71512965]
# [ 1.39] ~ [ 156.10333347]
# [ 1.78] ~ [ 146.70338159]
# [ 2.17] ~ [ 137.71734835]
# [ 2.56] ~ [ 129.28339016]
# [ 2.95] ~ [ 121.47515701]
# [ 3.34] ~ [ 114.31378054]
# [ 3.73] ~ [ 107.78394391]
# [ 4.12] ~ [ 101.84847936]
# [ 4.51] ~ [ 96.45933578]
# [ 4.9] ~ [ 91.56485998]
# [ 5.29] ~ [ 87.1141707]
# [ 5.68] ~ [ 83.05952072]
# [ 6.07] ~ [ 79.35738009]
# [ 6.46] ~ [ 75.96875927]
# [ 6.85] ~ [ 72.85911037]
# [ 7.24] ~ [ 69.99801525]
# [ 7.63] ~ [ 67.35878339]
# [ 8.02] ~ [ 64.91802875]
# [ 8.41] ~ [ 62.65526247]
# [ 8.8] ~ [ 60.55251875]
# [ 9.19] ~ [ 58.59402092]
# [ 9.58] ~ [ 56.76588815]
# [ 9.97] ~ [ 55.05588085]
# [ 10.36] ~ [ 53.45318096]
# [ 10.75] ~ [ 51.94820309]
# [ 11.14] ~ [ 50.53243248]
# [ 11.53] ~ [ 49.19828614]
# [ 11.92] ~ [ 47.93899374]
# [ 12.31] ~ [ 46.74849533]
# [ 12.7] ~ [ 45.62135352]
# [ 13.09] ~ [ 44.55267774]
# [ 13.48] ~ [ 43.53805896]
# [ 13.87] ~ [ 42.57351326]
# [ 14.26] ~ [ 41.65543288]
# [ 14.65] ~ [ 40.78054372]
# [ 15.04] ~ [ 39.94586833]
# [ 15.43] ~ [ 39.14869235]
# [ 15.82] ~ [ 38.38654159]
# [ 16.21] ~ [ 37.65714893]
# [ 16.6] ~ [ 36.95843835]
# [ 16.99] ~ [ 36.28850422]
# [ 17.38] ~ [ 35.64559435]
# [ 17.77] ~ [ 35.02809509]
# [ 18.16] ~ [ 34.43451795]
# [ 18.55] ~ [ 33.86348789]
# [ 18.94] ~ [ 33.31373275]
# [ 19.33] ~ [ 32.78407393]
# [ 19.72] ~ [ 32.27341796]
# [ 20.11] ~ [ 31.78074905]
# [ 20.5] ~ [ 31.30512234]
# [ 20.89] ~ [ 30.84565784]
# [ 21.28] ~ [ 30.40153504]
# [ 21.67] ~ [ 29.97198792]
# [ 22.06] ~ [ 29.5563006]
# [ 22.45] ~ [ 29.15380325]
# [ 22.84] ~ [ 28.76386854]
# [ 23.23] ~ [ 28.38590827]
# [ 23.62] ~ [ 28.01937041]
# [ 24.01] ~ [ 27.66373638]
# [ 24.4] ~ [ 27.31851853]
# [ 24.79] ~ [ 26.98325791]
# [ 25.18] ~ [ 26.65752216]
# [ 25.57] ~ [ 26.34090365]
# [ 25.96] ~ [ 26.03301773]
# [ 26.35] ~ [ 25.73350113]
# [ 26.74] ~ [ 25.4420105]
# [ 27.13] ~ [ 25.15822107]
# [ 27.52] ~ [ 24.88182541]
# [ 27.91] ~ [ 24.61253228]
# [ 28.3] ~ [ 24.3500656]
# [ 28.69] ~ [ 24.09416347]
# [ 29.08] ~ [ 23.84457725]
# [ 29.47] ~ [ 23.60107077]
# [ 29.86] ~ [ 23.36341953]
# [ 30.25] ~ [ 23.13140999]
# [ 30.64] ~ [ 22.90483892]
# [ 31.03] ~ [ 22.6835128]
# [ 31.42] ~ [ 22.46724719]
# [ 31.81] ~ [ 22.25586629]
# [ 32.2] ~ [ 22.04920235]
# [ 32.59] ~ [ 21.84709529]
# [ 32.98] ~ [ 21.6493922]
# [ 33.37] ~ [ 21.455947]
# [ 33.76] ~ [ 21.26662002]
# [ 34.15] ~ [ 21.0812777]
# [ 34.54] ~ [ 20.8997922]
# [ 34.93] ~ [ 20.72204114]
# [ 35.32] ~ [ 20.54790729]
# [ 35.71] ~ [ 20.37727831]
# [ 36.1] ~ [ 20.21004651]
# [ 36.49] ~ [ 20.04610858]
# [ 36.88] ~ [ 19.88536539]
# [ 37.27] ~ [ 19.72772178]
# [ 37.66] ~ [ 19.57308638]
# [ 38.05] ~ [ 19.42137137]
# [ 38.44] ~ [ 19.27249236]
# [ 38.83] ~ [ 19.1263682]
# [ 39.22] ~ [ 18.98292085]
# [ 39.61] ~ [ 18.84207518]
# [ 40.] ~ [ 18.70375889]
# [ 1.] ~ [ 165.95744773]
# [ 1.39] ~ [ 156.52309114]
# [ 1.78] ~ [ 147.28303321]
# [ 2.17] ~ [ 138.43141738]
# [ 2.56] ~ [ 130.10356275]
# [ 2.95] ~ [ 122.3743001]
# [ 3.34] ~ [ 115.26824373]
# [ 3.73] ~ [ 108.77438426]
# [ 4.12] ~ [ 102.85975718]
# [ 4.51] ~ [ 97.47996763]
# [ 4.9] ~ [ 92.58634158]
# [ 5.29] ~ [ 88.13033077]
# [ 5.68] ~ [ 84.0659701]
# [ 6.07] ~ [ 80.35106937]
# [ 6.46] ~ [ 76.94763552]
# [ 6.85] ~ [ 73.82185625]
# [ 7.24] ~ [ 70.94385299]
# [ 7.63] ~ [ 68.28732862]
# [ 8.02] ~ [ 65.82918186]
# [ 8.41] ~ [ 63.54912807]
# [ 8.8] ~ [ 61.42934598]
# [ 9.19] ~ [ 59.45415928]
# [ 9.58] ~ [ 57.60975483]
# [ 9.97] ~ [ 55.8839366]
# [ 10.36] ~ [ 54.26591234]
# [ 10.75] ~ [ 52.74610938]
# [ 11.14] ~ [ 51.31601624]
# [ 11.53] ~ [ 49.96804631]
# [ 11.92] ~ [ 48.69542078]
# [ 12.31] ~ [ 47.49206779]
# [ 12.7] ~ [ 46.35253572]
# [ 13.09] ~ [ 45.27191833]
# [ 13.48] ~ [ 44.24579003]
# [ 13.87] ~ [ 43.27014991]
# [ 14.26] ~ [ 42.34137315]
# [ 14.65] ~ [ 41.45616874]
# [ 15.04] ~ [ 40.61154269]
# [ 15.43] ~ [ 39.80476446]
# [ 15.82] ~ [ 39.03334435]
# [ 16.21] ~ [ 38.29500022]
# [ 16.6] ~ [ 37.58764166]
# [ 16.99] ~ [ 36.90934929]
# [ 17.38] ~ [ 36.25835783]
# [ 17.77] ~ [ 35.6330411]
# [ 18.16] ~ [ 35.03189876]
# [ 18.55] ~ [ 34.45354446]
# [ 18.94] ~ [ 33.89669535]
# [ 19.33] ~ [ 33.36016262]
# [ 19.72] ~ [ 32.84284319]
# [ 20.11] ~ [ 32.3437121]
# [ 20.5] ~ [ 31.86181582]
# [ 20.89] ~ [ 31.39626614]
# [ 21.28] ~ [ 30.94623474]
# [ 21.67] ~ [ 30.51094822]
# [ 22.06] ~ [ 30.08968366]
# [ 22.45] ~ [ 29.68176459]
# [ 22.84] ~ [ 29.28655735]
# [ 23.23] ~ [ 28.90346774]
# [ 23.62] ~ [ 28.53193806]
# [ 24.01] ~ [ 28.17144428]
# [ 24.4] ~ [ 27.82149362]
# [ 24.79] ~ [ 27.48162225]
# [ 25.18] ~ [ 27.15139315]
# [ 25.57] ~ [ 26.83039428]
# [ 25.96] ~ [ 26.51823675]
# [ 26.35] ~ [ 26.2145533]
# [ 26.74] ~ [ 25.91899674]
# [ 27.13] ~ [ 25.63123867]
# [ 27.52] ~ [ 25.35096817]
# [ 27.91] ~ [ 25.0778907]
# [ 28.3] ~ [ 24.81172702]
# [ 28.69] ~ [ 24.5522122]
# [ 29.08] ~ [ 24.29909472]
# [ 29.47] ~ [ 24.05213564]
# [ 29.86] ~ [ 23.81110784]
# [ 30.25] ~ [ 23.57579525]
# [ 30.64] ~ [ 23.34599223]
# [ 31.03] ~ [ 23.12150295]
# [ 31.42] ~ [ 22.90214076]
# [ 31.81] ~ [ 22.68772773]
# [ 32.2] ~ [ 22.4780941]
# [ 32.59] ~ [ 22.27307782]
# [ 32.98] ~ [ 22.07252413]
# [ 33.37] ~ [ 21.87628515]
# [ 33.76] ~ [ 21.6842195]
# [ 34.15] ~ [ 21.49619195]
# [ 34.54] ~ [ 21.31207309]
# [ 34.93] ~ [ 21.131739]
# [ 35.32] ~ [ 20.95507099]
# [ 35.71] ~ [ 20.78195532]
# [ 36.1] ~ [ 20.61228293]
# [ 36.49] ~ [ 20.44594921]
# [ 36.88] ~ [ 20.28285378]
# [ 37.27] ~ [ 20.12290028]
# [ 37.66] ~ [ 19.96599613]
# [ 38.05] ~ [ 19.81205243]
# [ 38.44] ~ [ 19.6609837]
# [ 38.83] ~ [ 19.51270773]
# [ 39.22] ~ [ 19.36714548]
# [ 39.61] ~ [ 19.22422085]
# [ 40.] ~ [ 19.08386062]
# [ 1.] ~ [ 166.21108337]
# [ 1.39] ~ [ 156.96857863]
# [ 1.78] ~ [ 147.90214037]
# [ 2.17] ~ [ 139.19741935]
# [ 2.56] ~ [ 130.9864626]
# [ 2.95] ~ [ 123.34505585]
# [ 3.34] ~ [ 116.30128386]
# [ 3.73] ~ [ 109.84859155]
# [ 4.12] ~ [ 103.95845165]
# [ 4.51] ~ [ 98.59038724]
# [ 4.9] ~ [ 93.69895489]
# [ 5.29] ~ [ 89.23816151]
# [ 5.68] ~ [ 85.1640106]
# [ 6.07] ~ [ 81.43580317]
# [ 6.46] ~ [ 78.01666306]
# [ 6.85] ~ [ 74.87360787]
# [ 7.24] ~ [ 71.97737178]
# [ 7.63] ~ [ 69.30210736]
# [ 8.02] ~ [ 66.82504119]
# [ 8.41] ~ [ 64.52612563]
# [ 8.8] ~ [ 62.38770879]
# [ 9.19] ~ [ 60.39423335]
# [ 9.58] ~ [ 58.53196781]
# [ 9.97] ~ [ 56.78876998]
# [ 10.36] ~ [ 55.15388083]
# [ 10.75] ~ [ 53.61774578]
# [ 11.14] ~ [ 52.17186023]
# [ 11.53] ~ [ 50.80863637]
# [ 11.92] ~ [ 49.52128828]
# [ 12.31] ~ [ 48.3037329]
# [ 12.7] ~ [ 47.15050452]
# [ 13.09] ~ [ 46.05668088]
# [ 13.48] ~ [ 45.01781924]
# [ 13.87] ~ [ 44.02990088]
# [ 14.26] ~ [ 43.08928293]
# [ 14.65] ~ [ 42.19265637]
# [ 15.04] ~ [ 41.33700945]
# [ 15.43] ~ [ 40.51959426]
# [ 15.82] ~ [ 39.73790436]
# [ 16.21] ~ [ 38.98964132]
# [ 16.6] ~ [ 38.27269913]
# [ 16.99] ~ [ 37.58514343]
# [ 17.38] ~ [ 36.92519466]
# [ 17.77] ~ [ 36.29121299]
# [ 18.16] ~ [ 35.68168509]
# [ 18.55] ~ [ 35.09521224]
# [ 18.94] ~ [ 34.53049982]
# [ 19.33] ~ [ 33.98634789]
# [ 19.72] ~ [ 33.46164272]
# [ 20.11] ~ [ 32.95534933]
# [ 20.5] ~ [ 32.46650461]
# [ 20.89] ~ [ 31.9942113]
# [ 21.28] ~ [ 31.53763246]
# [ 21.67] ~ [ 31.09598654]
# [ 22.06] ~ [ 30.66854287]
# [ 22.45] ~ [ 30.25461763]
# [ 22.84] ~ [ 29.85357017]
# [ 23.23] ~ [ 29.46479965]
# [ 23.62] ~ [ 29.08774207]
# [ 24.01] ~ [ 28.72186741]
# [ 24.4] ~ [ 28.3666772]
# [ 24.79] ~ [ 28.02170217]
# [ 25.18] ~ [ 27.68650017]
# [ 25.57] ~ [ 27.36065423]
# [ 25.96] ~ [ 27.04377081]
# [ 26.35] ~ [ 26.73547817]
# [ 26.74] ~ [ 26.43542492]
# [ 27.13] ~ [ 26.14327857]
# [ 27.52] ~ [ 25.85872437]
# [ 27.91] ~ [ 25.5814641]
# [ 28.3] ~ [ 25.31121498]
# [ 28.69] ~ [ 25.04770874]
# [ 29.08] ~ [ 24.79069066]
# [ 29.47] ~ [ 24.53991872]
# [ 29.86] ~ [ 24.29516287]
# [ 30.25] ~ [ 24.05620425]
# [ 30.64] ~ [ 23.82283453]
# [ 31.03] ~ [ 23.59485529]
# [ 31.42] ~ [ 23.37207745]
# [ 31.81] ~ [ 23.1543207]
# [ 32.2] ~ [ 22.94141302]
# [ 32.59] ~ [ 22.7331902]
# [ 32.98] ~ [ 22.52949541]
# [ 33.37] ~ [ 22.33017876]
# [ 33.76] ~ [ 22.13509695]
# [ 34.15] ~ [ 21.94411292]
# [ 34.54] ~ [ 21.75709549]
# [ 34.93] ~ [ 21.57391904]
# [ 35.32] ~ [ 21.39446325]
# [ 35.71] ~ [ 21.2186128]
# [ 36.1] ~ [ 21.04625712]
# [ 36.49] ~ [ 20.87729016]
# [ 36.88] ~ [ 20.71161012]
# [ 37.27] ~ [ 20.54911929]
# [ 37.66] ~ [ 20.38972381]
# [ 38.05] ~ [ 20.23333351]
# [ 38.44] ~ [ 20.0798617]
# [ 38.83] ~ [ 19.92922503]
# [ 39.22] ~ [ 19.78134331]
# [ 39.61] ~ [ 19.63613938]
# [ 40.] ~ [ 19.49353895]
# [ 1.] ~ [ 167.69497417]
# [ 1.39] ~ [ 159.82133722]
# [ 1.78] ~ [ 152.04602589]
# [ 2.17] ~ [ 144.49333035]
# [ 2.56] ~ [ 137.26129349]
# [ 2.95] ~ [ 130.41733289]
# [ 3.34] ~ [ 123.99959762]
# [ 3.73] ~ [ 118.02186082]
# [ 4.12] ~ [ 112.47969685]
# [ 4.51] ~ [ 107.35638441]
# [ 4.9] ~ [ 102.62776998]
# [ 5.29] ~ [ 98.26589949]
# [ 5.68] ~ [ 94.24153353]
# [ 6.07] ~ [ 90.52577558]
# [ 6.46] ~ [ 87.09105103]
# [ 6.85] ~ [ 83.91163747]
# [ 7.24] ~ [ 80.96389946]
# [ 7.63] ~ [ 78.22633687]
# [ 8.02] ~ [ 75.67952199]
# [ 8.41] ~ [ 73.30597475]
# [ 8.8] ~ [ 71.09000808]
# [ 9.19] ~ [ 69.01756301]
# [ 9.58] ~ [ 67.07604553]
# [ 9.97] ~ [ 65.25417172]
# [ 10.36] ~ [ 63.54182468]
# [ 10.75] ~ [ 61.92992453]
# [ 11.14] ~ [ 60.41031168]
# [ 11.53] ~ [ 58.97564289]
# [ 11.92] ~ [ 57.61929905]
# [ 12.31] ~ [ 56.33530386]
# [ 12.7] ~ [ 55.11825205]
# [ 13.09] ~ [ 53.96324626]
# [ 13.48] ~ [ 52.8658415]
# [ 13.87] ~ [ 51.82199622]
# [ 14.26] ~ [ 50.82802928]
# [ 14.65] ~ [ 49.88058205]
# [ 15.04] ~ [ 48.9765849]
# [ 15.43] ~ [ 48.1132277]
# [ 15.82] ~ [ 47.28793231]
# [ 16.21] ~ [ 46.49833493]
# [ 16.6] ~ [ 45.7422571]
# [ 16.99] ~ [ 45.01769332]
# [ 17.38] ~ [ 44.32279323]
# [ 17.77] ~ [ 43.65584723]
# [ 18.16] ~ [ 43.01527348]
# [ 18.55] ~ [ 42.39960643]
# [ 18.94] ~ [ 41.80748639]
# [ 19.33] ~ [ 41.23765033]
# [ 19.72] ~ [ 40.68892347]
# [ 20.11] ~ [ 40.16021183]
# [ 20.5] ~ [ 39.65049542]
# [ 20.89] ~ [ 39.15882217]
# [ 21.28] ~ [ 38.68430238]
# [ 21.67] ~ [ 38.22610375]
# [ 22.06] ~ [ 37.78344683]
# [ 22.45] ~ [ 37.35560089]
# [ 22.84] ~ [ 36.94188024]
# [ 23.23] ~ [ 36.54164075]
# [ 23.62] ~ [ 36.15427682]
# [ 24.01] ~ [ 35.77921847]
# [ 24.4] ~ [ 35.41592882]
# [ 24.79] ~ [ 35.06390169]
# [ 25.18] ~ [ 34.72265944]
# [ 25.57] ~ [ 34.39175095]
# [ 25.96] ~ [ 34.07074986]
# [ 26.35] ~ [ 33.75925282]
# [ 26.74] ~ [ 33.45687798]
# [ 27.13] ~ [ 33.16326358]
# [ 27.52] ~ [ 32.87806662]
# [ 27.91] ~ [ 32.60096163]
# [ 28.3] ~ [ 32.33163959]
# [ 28.69] ~ [ 32.06980687]
# [ 29.08] ~ [ 31.81518431]
# [ 29.47] ~ [ 31.56750626]
# [ 29.86] ~ [ 31.32651982]
# [ 30.25] ~ [ 31.09198408]
# [ 30.64] ~ [ 30.86366936]
# [ 31.03] ~ [ 30.64135659]
# [ 31.42] ~ [ 30.42483668]
# [ 31.81] ~ [ 30.21390998]
# [ 32.2] ~ [ 30.0083857]
# [ 32.59] ~ [ 29.80808144]
# [ 32.98] ~ [ 29.61282273]
# [ 33.37] ~ [ 29.4224426]
# [ 33.76] ~ [ 29.23678114]
# [ 34.15] ~ [ 29.05568517]
# [ 34.54] ~ [ 28.87900786]
# [ 34.93] ~ [ 28.70660841]
# [ 35.32] ~ [ 28.53835171]
# [ 35.71] ~ [ 28.37410811]
# [ 36.1] ~ [ 28.21375306]
# [ 36.49] ~ [ 28.05716693]
# [ 36.88] ~ [ 27.90423474]
# [ 37.27] ~ [ 27.75484591]
# [ 37.66] ~ [ 27.6088941]
# [ 38.05] ~ [ 27.46627696]
# [ 38.44] ~ [ 27.32689594]
# [ 38.83] ~ [ 27.19065616]
# [ 39.22] ~ [ 27.0574662]
# [ 39.61] ~ [ 26.92723795]
# [ 40.] ~ [ 26.79988647]
# [ 1.] ~ [ 168.09356216]
# [ 1.39] ~ [ 160.74919086]
# [ 1.78] ~ [ 153.50502837]
# [ 2.17] ~ [ 146.46235326]
# [ 2.56] ~ [ 139.70200944]
# [ 2.95] ~ [ 133.2811756]
# [ 3.34] ~ [ 127.23409677]
# [ 3.73] ~ [ 121.57540125]
# [ 4.12] ~ [ 116.30452377]
# [ 4.51] ~ [ 111.4101315]
# [ 4.9] ~ [ 106.87394007]
# [ 5.29] ~ [ 102.67369928]
# [ 5.68] ~ [ 98.78536584]
# [ 6.07] ~ [ 95.1845906]
# [ 6.46] ~ [ 91.84767607]
# [ 6.85] ~ [ 88.75214903]
# [ 7.24] ~ [ 85.87706586]
# [ 7.63] ~ [ 83.20313972]
# [ 8.02] ~ [ 80.7127537]
# [ 8.41] ~ [ 78.3899047]
# [ 8.8] ~ [ 76.22010796]
# [ 9.19] ~ [ 74.1902821]
# [ 9.58] ~ [ 72.28862735]
# [ 9.97] ~ [ 70.5045047]
# [ 10.36] ~ [ 68.82832045]
# [ 10.75] ~ [ 67.25141877]
# [ 11.14] ~ [ 65.76598322]
# [ 11.53] ~ [ 64.36494754]
# [ 11.92] ~ [ 63.04191549]
# [ 12.31] ~ [ 61.79108919]
# [ 12.7] ~ [ 60.60720532]
# [ 13.09] ~ [ 59.48547837]
# [ 13.48] ~ [ 58.4215504]
# [ 13.87] ~ [ 57.41144642]
# [ 14.26] ~ [ 56.45153485]
# [ 14.65] ~ [ 55.53849254]
# [ 15.04] ~ [ 54.66927226]
# [ 15.43] ~ [ 53.84108107]
# [ 15.82] ~ [ 53.0513466]
# [ 16.21] ~ [ 52.29770166]
# [ 16.6] ~ [ 51.57796321]
# [ 16.99] ~ [ 50.89011504]
# [ 17.38] ~ [ 50.23229238]
# [ 17.77] ~ [ 49.60276813]
# [ 18.16] ~ [ 48.99994044]
# [ 18.55] ~ [ 48.42232173]
# [ 18.94] ~ [ 47.86852872]
# [ 19.33] ~ [ 47.33727352]
# [ 19.72] ~ [ 46.82735557]
# [ 20.11] ~ [ 46.33765444]
# [ 20.5] ~ [ 45.86712323]
# [ 20.89] ~ [ 45.41478272]
# [ 21.28] ~ [ 44.97971597]
# [ 21.67] ~ [ 44.56106351]
# [ 22.06] ~ [ 44.15801888]
# [ 22.45] ~ [ 43.76982468]
# [ 22.84] ~ [ 43.39576888]
# [ 23.23] ~ [ 43.03518155]
# [ 23.62] ~ [ 42.68743175]
# [ 24.01] ~ [ 42.35192484]
# [ 24.4] ~ [ 42.02809987]
# [ 24.79] ~ [ 41.71542732]
# [ 25.18] ~ [ 41.41340691]
# [ 25.57] ~ [ 41.12156567]
# [ 25.96] ~ [ 40.83945615]
# [ 26.35] ~ [ 40.56665472]
# [ 26.74] ~ [ 40.30276007]
# [ 27.13] ~ [ 40.04739182]
# [ 27.52] ~ [ 39.80018913]
# [ 27.91] ~ [ 39.56080959]
# [ 28.3] ~ [ 39.32892804]
# [ 28.69] ~ [ 39.10423555]
# [ 29.08] ~ [ 38.88643846]
# [ 29.47] ~ [ 38.67525748]
# [ 29.86] ~ [ 38.47042686]
# [ 30.25] ~ [ 38.27169361]
# [ 30.64] ~ [ 38.07881679]
# [ 31.03] ~ [ 37.89156682]
# [ 31.42] ~ [ 37.70972485]
# [ 31.81] ~ [ 37.53308219]
# [ 32.2] ~ [ 37.36143974]
# [ 32.59] ~ [ 37.19460749]
# [ 32.98] ~ [ 37.03240402]
# [ 33.37] ~ [ 36.87465605]
# [ 33.76] ~ [ 36.72119805]
# [ 34.15] ~ [ 36.57187177]
# [ 34.54] ~ [ 36.42652595]
# [ 34.93] ~ [ 36.28501587]
# [ 35.32] ~ [ 36.14720312]
# [ 35.71] ~ [ 36.01295521]
# [ 36.1] ~ [ 35.8821453]
# [ 36.49] ~ [ 35.75465193]
# [ 36.88] ~ [ 35.63035877]
# [ 37.27] ~ [ 35.50915431]
# [ 37.66] ~ [ 35.3909317]
# [ 38.05] ~ [ 35.27558849]
# [ 38.44] ~ [ 35.16302643]
# [ 38.83] ~ [ 35.05315127]
# [ 39.22] ~ [ 34.94587257]
# [ 39.61] ~ [ 34.84110352]
# [ 40.] ~ [ 34.73876079]
# [ 1.] ~ [ 168.47589624]
# [ 1.39] ~ [ 161.91654122]
# [ 1.78] ~ [ 155.48755635]
# [ 2.17] ~ [ 149.25978643]
# [ 2.56] ~ [ 143.28869537]
# [ 2.95] ~ [ 137.61319861]
# [ 3.34] ~ [ 132.25659262]
# [ 3.73] ~ [ 127.22881303]
# [ 4.12] ~ [ 122.52925974]
# [ 4.51] ~ [ 118.14961985]
# [ 4.9] ~ [ 114.07635567]
# [ 5.29] ~ [ 110.29271982]
# [ 5.68] ~ [ 106.78028645]
# [ 6.07] ~ [ 103.52005427]
# [ 6.46] ~ [ 100.49320214]
# [ 6.85] ~ [ 97.68157849]
# [ 7.24] ~ [ 95.06799584]
# [ 7.63] ~ [ 92.6363876]
# [ 8.02] ~ [ 90.37187081]
# [ 8.41] ~ [ 88.26074697]
# [ 8.8] ~ [ 86.29046385]
# [ 9.19] ~ [ 84.44955421]
# [ 9.58] ~ [ 82.72756234]
# [ 9.97] ~ [ 81.11496572]
# [ 10.36] ~ [ 79.6030962]
# [ 10.75] ~ [ 78.18406397]
# [ 11.14] ~ [ 76.85068558]
# [ 11.53] ~ [ 75.59641718]
# [ 11.92] ~ [ 74.41529323]
# [ 12.31] ~ [ 73.30187064]
# [ 12.7] ~ [ 72.25117817]
# [ 13.09] ~ [ 71.25867086]
# [ 13.48] ~ [ 70.32018895]
# [ 13.87] ~ [ 69.43192103]
# [ 14.26] ~ [ 68.590371]
# [ 14.65] ~ [ 67.79232842]
# [ 15.04] ~ [ 67.03484189]
# [ 15.43] ~ [ 66.31519524]
# [ 15.82] ~ [ 65.6308861]
# [ 16.21] ~ [ 64.97960668]
# [ 16.6] ~ [ 64.35922644]
# [ 16.99] ~ [ 63.76777659]
# [ 17.38] ~ [ 63.20343597]
# [ 17.77] ~ [ 62.66451845]
# [ 18.16] ~ [ 62.14946147]
# [ 18.55] ~ [ 61.65681571]
# [ 18.94] ~ [ 61.18523567]
# [ 19.33] ~ [ 60.73347121]
# [ 19.72] ~ [ 60.30035985]
# [ 20.11] ~ [ 59.88481968]
# [ 20.5] ~ [ 59.48584307]
# [ 20.89] ~ [ 59.10249078]
# [ 21.28] ~ [ 58.73388667]
# [ 21.67] ~ [ 58.3792129]
# [ 22.06] ~ [ 58.03770544]
# [ 22.45] ~ [ 57.70865004]
# [ 22.84] ~ [ 57.39137856]
# [ 23.23] ~ [ 57.08526548]
# [ 23.62] ~ [ 56.78972488]
# [ 24.01] ~ [ 56.50420766]
# [ 24.4] ~ [ 56.2281983]
# [ 24.79] ~ [ 55.96121341]
# [ 25.18] ~ [ 55.70279881]
# [ 25.57] ~ [ 55.45252769]
# [ 25.96] ~ [ 55.20999869]
# [ 26.35] ~ [ 54.97483413]
# [ 26.74] ~ [ 54.74667846]
# [ 27.13] ~ [ 54.52519671]
# [ 27.52] ~ [ 54.31007316]
# [ 27.91] ~ [ 54.10100999]
# [ 28.3] ~ [ 53.89772621]
# [ 28.69] ~ [ 53.69995647]
# [ 29.08] ~ [ 53.5074501]
# [ 29.47] ~ [ 53.31997014]
# [ 29.86] ~ [ 53.13729251]
# [ 30.25] ~ [ 52.95920514]
# [ 30.64] ~ [ 52.78550727]
# [ 31.03] ~ [ 52.61600872]
# [ 31.42] ~ [ 52.45052927]
# [ 31.81] ~ [ 52.28889802]
# [ 32.2] ~ [ 52.13095284]
# [ 32.59] ~ [ 51.97653984]
# [ 32.98] ~ [ 51.82551291]
# [ 33.37] ~ [ 51.67773321]
# [ 33.76] ~ [ 51.53306879]
# [ 34.15] ~ [ 51.39139415]
# [ 34.54] ~ [ 51.25258992]
# [ 34.93] ~ [ 51.11654247]
# [ 35.32] ~ [ 50.98314359]
# [ 35.71] ~ [ 50.85229021]
# [ 36.1] ~ [ 50.72388407]
# [ 36.49] ~ [ 50.59783152]
# [ 36.88] ~ [ 50.47404319]
# [ 37.27] ~ [ 50.35243382]
# [ 37.66] ~ [ 50.23292202]
# [ 38.05] ~ [ 50.11543004]
# [ 38.44] ~ [ 49.9998836]
# [ 38.83] ~ [ 49.88621171]
# [ 39.22] ~ [ 49.77434649]
# [ 39.61] ~ [ 49.66422301]
# [ 40.] ~ [ 49.55577914]
# [ 1.] ~ [ 168.3122016]
# [ 1.39] ~ [ 163.01136135]
# [ 1.78] ~ [ 157.92806621]
# [ 2.17] ~ [ 153.09277906]
# [ 2.56] ~ [ 148.52444497]
# [ 2.95] ~ [ 144.23188384]
# [ 3.34] ~ [ 140.21563618]
# [ 3.73] ~ [ 136.46990449]
# [ 4.12] ~ [ 132.98435403]
# [ 4.51] ~ [ 129.74564972]
# [ 4.9] ~ [ 126.73868925]
# [ 5.29] ~ [ 123.94754372]
# [ 5.68] ~ [ 121.35614366]
# [ 6.07] ~ [ 118.94875691]
# [ 6.46] ~ [ 116.71030424]
# [ 6.85] ~ [ 114.6265529]
# [ 7.24] ~ [ 112.68422119]
# [ 7.63] ~ [ 110.87102007]
# [ 8.02] ~ [ 109.17565167]
# [ 8.41] ~ [ 107.58777915]
# [ 8.8] ~ [ 106.09797903]
# [ 9.19] ~ [ 104.69768306]
# [ 9.58] ~ [ 103.37911548]
# [ 9.97] ~ [ 102.13522884]
# [ 10.36] ~ [ 100.95964112]
# [ 10.75] ~ [ 99.8465754]
# [ 11.14] ~ [ 98.79080322]
# [ 11.53] ~ [ 97.78759189]
# [ 11.92] ~ [ 96.83265609]
# [ 12.31] ~ [ 95.92211365]
# [ 12.7] ~ [ 95.05244537]
# [ 13.09] ~ [ 94.22045872]
# [ 13.48] ~ [ 93.42325509]
# [ 13.87] ~ [ 92.6582003]
# [ 14.26] ~ [ 91.92289823]
# [ 14.65] ~ [ 91.21516702]
# [ 15.04] ~ [ 90.53301791]
# [ 15.43] ~ [ 89.87463616]
# [ 15.82] ~ [ 89.238364]
# [ 16.21] ~ [ 88.62268547]
# [ 16.6] ~ [ 88.02621266]
# [ 16.99] ~ [ 87.44767353]
# [ 17.38] ~ [ 86.88590097]
# [ 17.77] ~ [ 86.33982292]
# [ 18.16] ~ [ 85.80845358]
# [ 18.55] ~ [ 85.29088549]
# [ 18.94] ~ [ 84.78628239]
# [ 19.33] ~ [ 84.29387287]
# [ 19.72] ~ [ 83.81294454]
# [ 20.11] ~ [ 83.34283889]
# [ 20.5] ~ [ 82.88294657]
# [ 20.89] ~ [ 82.43270319]
# [ 21.28] ~ [ 81.99158548]
# [ 21.67] ~ [ 81.55910784]
# [ 22.06] ~ [ 81.13481919]
# [ 22.45] ~ [ 80.71830016]
# [ 22.84] ~ [ 80.30916049]
# [ 23.23] ~ [ 79.90703671]
# [ 23.62] ~ [ 79.51159022]
# [ 24.01] ~ [ 79.12250442]
# [ 24.4] ~ [ 78.73948439]
# [ 24.79] ~ [ 78.36225432]
# [ 25.18] ~ [ 77.99055623]
# [ 25.57] ~ [ 77.62414868]
# [ 25.96] ~ [ 77.26280553]
# [ 26.35] ~ [ 76.90631481]
# [ 26.74] ~ [ 76.55447767]
# [ 27.13] ~ [ 76.20710747]
# [ 27.52] ~ [ 75.86402888]
# [ 27.91] ~ [ 75.52507708]
# [ 28.3] ~ [ 75.19009706]
# [ 28.69] ~ [ 74.85894291]
# [ 29.08] ~ [ 74.5314772]
# [ 29.47] ~ [ 74.20757042]
# [ 29.86] ~ [ 73.88710043]
# [ 30.25] ~ [ 73.56995198]
# [ 30.64] ~ [ 73.25601625]
# [ 31.03] ~ [ 72.94519046]
# [ 31.42] ~ [ 72.63737741]
# [ 31.81] ~ [ 72.3324852]
# [ 32.2] ~ [ 72.03042685]
# [ 32.59] ~ [ 71.73112]
# [ 32.98] ~ [ 71.4344866]
# [ 33.37] ~ [ 71.14045268]
# [ 33.76] ~ [ 70.8489481]
# [ 34.15] ~ [ 70.55990626]
# [ 34.54] ~ [ 70.27326395]
# [ 34.93] ~ [ 69.98896112]
# [ 35.32] ~ [ 69.70694067]
# [ 35.71] ~ [ 69.42714834]
# [ 36.1] ~ [ 69.14953246]
# [ 36.49] ~ [ 68.87404386]
# [ 36.88] ~ [ 68.60063572]
# [ 37.27] ~ [ 68.32926339]
# [ 37.66] ~ [ 68.05988432]
# [ 38.05] ~ [ 67.79245791]
# [ 38.44] ~ [ 67.52694541]
# [ 38.83] ~ [ 67.26330981]
# [ 39.22] ~ [ 67.00151577]
# [ 39.61] ~ [ 66.74152948]
# [ 40.] ~ [ 66.4833186]
# [ 1.] ~ [ 161.0829455]
# [ 1.39] ~ [ 157.22779673]
# [ 1.78] ~ [ 153.63752715]
# [ 2.17] ~ [ 150.2885979]
# [ 2.56] ~ [ 147.15738694]
# [ 2.95] ~ [ 144.22158379]
# [ 3.34] ~ [ 141.46086044]
# [ 3.73] ~ [ 138.85709213]
# [ 4.12] ~ [ 136.3943232]
# [ 4.51] ~ [ 134.05860427]
# [ 4.9] ~ [ 131.83777683]
# [ 5.29] ~ [ 129.72124748]
# [ 5.68] ~ [ 127.6997738]
# [ 6.07] ~ [ 125.76527159]
# [ 6.46] ~ [ 123.9106463]
# [ 6.85] ~ [ 122.12964845]
# [ 7.24] ~ [ 120.41675084]
# [ 7.63] ~ [ 118.76704488]
# [ 8.02] ~ [ 117.1761533]
# [ 8.41] ~ [ 115.6401568]
# [ 8.8] ~ [ 114.1555322]
# [ 9.19] ~ [ 112.71910036]
# [ 9.58] ~ [ 111.3279821]
# [ 9.97] ~ [ 109.97956081]
# [ 10.36] ~ [ 108.67145066]
# [ 10.75] ~ [ 107.40146942]
# [ 11.14] ~ [ 106.16761521]
# [ 11.53] ~ [ 104.96804639]
# [ 11.92] ~ [ 103.80106433]
# [ 12.31] ~ [ 102.66509836]
# [ 12.7] ~ [ 101.55869274]
# [ 13.09] ~ [ 100.48049522]
# [ 13.48] ~ [ 99.42924711]
# [ 13.87] ~ [ 98.40377442]
# [ 14.26] ~ [ 97.40298017]
# [ 14.65] ~ [ 96.42583756]
# [ 15.04] ~ [ 95.47138358]
# [ 15.43] ~ [ 94.5387141]
# [ 15.82] ~ [ 93.62697863]
# [ 16.21] ~ [ 92.73537611]
# [ 16.6] ~ [ 91.86315099]
# [ 16.99] ~ [ 91.00958974]
# [ 17.38] ~ [ 90.17401768]
# [ 17.77] ~ [ 89.35579613]
# [ 18.16] ~ [ 88.55431976]
# [ 18.55] ~ [ 87.76901431]
# [ 18.94] ~ [ 86.99933437]
# [ 19.33] ~ [ 86.24476149]
# [ 19.72] ~ [ 85.50480232]
# [ 20.11] ~ [ 84.77898702]
# [ 20.5] ~ [ 84.06686774]
# [ 20.89] ~ [ 83.36801725]
# [ 21.28] ~ [ 82.68202763]
# [ 21.67] ~ [ 82.00850914]
# [ 22.06] ~ [ 81.34708912]
# [ 22.45] ~ [ 80.697411]
# [ 22.84] ~ [ 80.05913335]
# [ 23.23] ~ [ 79.43192903]
# [ 23.62] ~ [ 78.81548441]
# [ 24.01] ~ [ 78.20949862]
# [ 24.4] ~ [ 77.61368284]
# [ 24.79] ~ [ 77.02775968]
# [ 25.18] ~ [ 76.45146257]
# [ 25.57] ~ [ 75.8845352]
# [ 25.96] ~ [ 75.32673102]
# [ 26.35] ~ [ 74.77781269]
# [ 26.74] ~ [ 74.23755169]
# [ 27.13] ~ [ 73.70572786]
# [ 27.52] ~ [ 73.18212897]
# [ 27.91] ~ [ 72.6665504]
# [ 28.3] ~ [ 72.15879472]
# [ 28.69] ~ [ 71.65867141]
# [ 29.08] ~ [ 71.1659965]
# [ 29.47] ~ [ 70.68059229]
# [ 29.86] ~ [ 70.20228709]
# [ 30.25] ~ [ 69.7309149]
# [ 30.64] ~ [ 69.26631522]
# [ 31.03] ~ [ 68.80833278]
# [ 31.42] ~ [ 68.35681733]
# [ 31.81] ~ [ 67.9116234]
# [ 32.2] ~ [ 67.47261014]
# [ 32.59] ~ [ 67.0396411]
# [ 32.98] ~ [ 66.61258406]
# [ 33.37] ~ [ 66.19131086]
# [ 33.76] ~ [ 65.77569724]
# [ 34.15] ~ [ 65.36562267]
# [ 34.54] ~ [ 64.96097022]
# [ 34.93] ~ [ 64.56162642]
# [ 35.32] ~ [ 64.16748109]
# [ 35.71] ~ [ 63.77842729]
# [ 36.1] ~ [ 63.39436113]
# [ 36.49] ~ [ 63.01518167]
# [ 36.88] ~ [ 62.64079084]
# [ 37.27] ~ [ 62.27109329]
# [ 37.66] ~ [ 61.90599635]
# [ 38.05] ~ [ 61.54540986]
# [ 38.44] ~ [ 61.18924615]
# [ 38.83] ~ [ 60.8374199]
# [ 39.22] ~ [ 60.48984809]
# [ 39.61] ~ [ 60.14644991]
# [ 40.] ~ [ 59.80714667]
# [ 1.] ~ [ 101.58417136]
# [ 1.39] ~ [ 99.81693602]
# [ 1.78] ~ [ 98.14556349]
# [ 2.17] ~ [ 96.56013623]
# [ 2.56] ~ [ 95.05225674]
# [ 2.95] ~ [ 93.61474476]
# [ 3.34] ~ [ 92.24140732]
# [ 3.73] ~ [ 90.92686151]
# [ 4.12] ~ [ 89.66639578]
# [ 4.51] ~ [ 88.45586021]
# [ 4.9] ~ [ 87.29157804]
# [ 5.29] ~ [ 86.1702771]
# [ 5.68] ~ [ 85.08902783]
# [ 6.07] ~ [ 84.04519822]
# [ 6.46] ~ [ 83.03641343]
# [ 6.85] ~ [ 82.06052266]
# [ 7.24] ~ [ 81.1155712]
# [ 7.63] ~ [ 80.19977686]
# [ 8.02] ~ [ 79.31150981]
# [ 8.41] ~ [ 78.44927538]
# [ 8.8] ~ [ 77.61169921]
# [ 9.19] ~ [ 76.79751443]
# [ 9.58] ~ [ 76.00555058]
# [ 9.97] ~ [ 75.23472384]
# [ 10.36] ~ [ 74.48402855]
# [ 10.75] ~ [ 73.75252976]
# [ 11.14] ~ [ 73.03935665]
# [ 11.53] ~ [ 72.34369667]
# [ 11.92] ~ [ 71.6647904]
# [ 12.31] ~ [ 71.00192695]
# [ 12.7] ~ [ 70.35443982]
# [ 13.09] ~ [ 69.72170327]
# [ 13.48] ~ [ 69.10312898]
# [ 13.87] ~ [ 68.49816312]
# [ 14.26] ~ [ 67.90628364]
# [ 14.65] ~ [ 67.32699787]
# [ 15.04] ~ [ 66.75984032]
# [ 15.43] ~ [ 66.20437074]
# [ 15.82] ~ [ 65.66017222]
# [ 16.21] ~ [ 65.12684963]
# [ 16.6] ~ [ 64.60402808]
# [ 16.99] ~ [ 64.09135156]
# [ 17.38] ~ [ 63.58848166]
# [ 17.77] ~ [ 63.09509646]
# [ 18.16] ~ [ 62.61088941]
# [ 18.55] ~ [ 62.13556841]
# [ 18.94] ~ [ 61.6688549]
# [ 19.33] ~ [ 61.21048298]
# [ 19.72] ~ [ 60.76019874]
# [ 20.11] ~ [ 60.31775946]
# [ 20.5] ~ [ 59.88293301]
# [ 20.89] ~ [ 59.45549721]
# [ 21.28] ~ [ 59.0352393]
# [ 21.67] ~ [ 58.62195537]
# [ 22.06] ~ [ 58.21544991]
# [ 22.45] ~ [ 57.81553535]
# [ 22.84] ~ [ 57.4220316]
# [ 23.23] ~ [ 57.0347657]
# [ 23.62] ~ [ 56.65357142]
# [ 24.01] ~ [ 56.27828892]
# [ 24.4] ~ [ 55.90876445]
# [ 24.79] ~ [ 55.54485]
# [ 25.18] ~ [ 55.18640305]
# [ 25.57] ~ [ 54.8332863]
# [ 25.96] ~ [ 54.4853674]
# [ 26.35] ~ [ 54.14251874]
# [ 26.74] ~ [ 53.80461721]
# [ 27.13] ~ [ 53.47154398]
# [ 27.52] ~ [ 53.14318433]
# [ 27.91] ~ [ 52.81942745]
# [ 28.3] ~ [ 52.50016628]
# [ 28.69] ~ [ 52.1852973]
# [ 29.08] ~ [ 51.87472043]
# [ 29.47] ~ [ 51.56833885]
# [ 29.86] ~ [ 51.26605886]
# [ 30.25] ~ [ 50.96778975]
# [ 30.64] ~ [ 50.6734437]
# [ 31.03] ~ [ 50.38293561]
# [ 31.42] ~ [ 50.09618304]
# [ 31.81] ~ [ 49.81310607]
# [ 32.2] ~ [ 49.5336272]
# [ 32.59] ~ [ 49.25767126]
# [ 32.98] ~ [ 48.98516534]
# [ 33.37] ~ [ 48.71603867]
# [ 33.76] ~ [ 48.45022252]
# [ 34.15] ~ [ 48.18765019]
# [ 34.54] ~ [ 47.92825688]
# [ 34.93] ~ [ 47.67197962]
# [ 35.32] ~ [ 47.41875722]
# [ 35.71] ~ [ 47.16853021]
# [ 36.1] ~ [ 46.92124073]
# [ 36.49] ~ [ 46.67683256]
# [ 36.88] ~ [ 46.43525095]
# [ 37.27] ~ [ 46.19644267]
# [ 37.66] ~ [ 45.9603559]
# [ 38.05] ~ [ 45.72694017]
# [ 38.44] ~ [ 45.49614636]
# [ 38.83] ~ [ 45.26792663]
# [ 39.22] ~ [ 45.04223437]
# [ 39.61] ~ [ 44.81902416]
# [ 40.] ~ [ 44.59825173]
# ---------------------------------------------------------------------------
# PlotlyDictValueError                      Traceback (most recent call last)
# <ipython-input-2-3b6c40b69027> in <module>()
#      23         dgs = tellurium.executeCombineArchive(f, printPython=False, outputDir=outputDir, saveOutputs=True)
#      24
# ---> 25 dgs = tellurium.executeCombineArchive("./omex/L1V3_parameter-scan-2d.omex", printPython=True, outputDir=outputDir, saveOutputs=True)
#
# ~/git/tellurium/tellurium/sedml/tesedml.py in executeCombineArchive(omexPath, workingDir, printPython, createOutputs, saveOutputs, outputDir, plottingEngine)
#     337                     print(code)
#     338
# --> 339                 results[sedmlFile] = factory.executePython()
#     340
#     341             return results
#
# ~/git/tellurium/tellurium/sedml/tesedml.py in executePython(self)
#     486             # Use of exec carries the usual security warnings
#     487             symbols = {}
# --> 488             exec(compile(code, filename, 'exec'), symbols)
#     489
#     490             # read information from exec symbols
#
# /tmp/te-generated-sedml.py in <module>()
#     142     print(__xitem__, '~', __yitem__)
#     143     tefig.addXYDataset(__xitem__, __yitem__, color='C1', tag='tag1', **extra_args)
# --> 144 fig = tefig.render()
#     145
#     146 if str(_engine) == '<MatplotlibEngine>':
#
# ~/git/tellurium/tellurium/plotting/engine_plotly.py in render(self)
#      59                 x = dataset['x'],
#      60                 y = dataset['y'],
# ---> 61                 **kwargs
#      62             ))
#      63
#
# ~/envs/tellurium/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __init__(self, *args, **kwargs)
#     375         d = {key: val for key, val in dict(*args, **kwargs).items()}
#     376         for key, val in d.items():
# --> 377             self.__setitem__(key, val, _raise=_raise)
#     378
#     379     def __dir__(self):
#
# ~/envs/tellurium/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __setitem__(self, key, value, _raise)
#     430
#     431         if self._get_attribute_role(key) == 'object':
# --> 432             value = self._value_to_graph_object(key, value, _raise=_raise)
#     433             if not isinstance(value, (PlotlyDict, PlotlyList)):
#     434                 return
#
# ~/envs/tellurium/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in _value_to_graph_object(self, key, value, _raise)
#     535             if _raise:
#     536                 path = self._get_path() + (key, )
# --> 537                 raise exceptions.PlotlyDictValueError(self, path)
#     538             else:
#     539                 return
#
# PlotlyDictValueError: 'marker' has invalid value inside 'scatter'
#
# Path To Error: ['marker']
#
# Current path: []
# Current parent object_names: []
#
# With the current parents, 'marker' can be used as follows:
#
# Under ('figure', 'data', 'scatter'):
#
#     role: object
